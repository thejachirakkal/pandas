# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba\pandas_docs (1)
#
# 07/26/2023  09:30 AM    <DIR>          .
# 07/25/2023  09:14 PM    <DIR>          ..
# 07/25/2023  08:08 PM    <DIR>          .ipynb_checkpoints
# 07/26/2023  09:30 AM            71,378 ASSIGNMENT.ipynb
# 07/23/2023  05:31 PM               111 csv_mindex.csv
# 07/25/2023  09:34 AM           210,614 DATA ANALYSIS - WRK1.ipynb
# 07/24/2023  09:58 AM                87 data4new.csv
# 07/23/2023  05:31 PM                59 demo1.csv
# 07/23/2023  05:31 PM            10,545 demo1.xlsx
# 07/23/2023  05:31 PM                43 demo2.csv
# 07/23/2023  05:31 PM               169 demo3.csv
# 07/23/2023  05:31 PM               170 demo3.txt
# 07/23/2023  05:31 PM               169 demo4.csv
# 07/23/2023  05:31 PM                78 demo5.csv
# 07/23/2023  05:31 PM           626,863 demo6.csv
# 07/23/2023  05:31 PM                36 demo7.csv
# ...

# %%
data=pd.read_csv('stock_px.csv',index_col=[0])
data
# Out:
#                         AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                    ...     ...    ...     ...    ...    ...    ...
# 2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#                          SPX    XOM
# 1990-02-01 00:00:00   328.79   6.12
# 1990-02-02 00:00:00   330.92   6.24
# ...

# %%
data.shape
# Out:
# (5472, 9)

# %%
data.size
# Out:
# 49248

# %%
data.iloc[[15,3000],3]
# Out:
# 1990-02-23 00:00:00     17.84
# 2001-12-21 00:00:00    107.33
# Name: IBM, dtype: float64

# %%
data.iloc[0:21,2]
# Out:
# 1990-02-01 00:00:00    2.87
# 1990-02-02 00:00:00    2.87
# 1990-02-05 00:00:00    2.87
# 1990-02-06 00:00:00    2.88
# 1990-02-07 00:00:00    2.91
# 1990-02-08 00:00:00    2.92
# 1990-02-09 00:00:00    2.94
# 1990-02-12 00:00:00    2.89
# 1990-02-13 00:00:00    2.88
# 1990-02-14 00:00:00    2.89
# 1990-02-15 00:00:00    2.91
# 1990-02-16 00:00:00    2.88
# 1990-02-20 00:00:00    2.83
# 1990-02-21 00:00:00    2.81
# 1990-02-22 00:00:00    2.82
# 1990-02-23 00:00:00    2.81
# 1990-02-26 00:00:00    2.84
# 1990-02-27 00:00:00    2.88
# 1990-02-28 00:00:00    2.89
# 1990-03-01 00:00:00    2.88
# 1990-03-02 00:00:00    2.92
# Name: GE, dtype: float64

# %%
data.iloc[50:101,[1,3,5]]
# Out:
#                       AAPL    IBM  MSFT
# 1990-04-16 00:00:00  10.25  19.28  0.66
# 1990-04-17 00:00:00  10.13  19.32  0.68
# 1990-04-18 00:00:00  10.13  19.10  0.66
# 1990-04-19 00:00:00   9.43  18.97  0.65
# 1990-04-20 00:00:00   9.43  19.01  0.65
# 1990-04-23 00:00:00   9.31  19.01  0.64
# 1990-04-24 00:00:00   9.08  18.93  0.63
# 1990-04-25 00:00:00   9.08  19.01  0.63
# 1990-04-26 00:00:00   9.11  18.91  0.63
# 1990-04-27 00:00:00   9.17  18.67  0.61
# 1990-04-30 00:00:00   9.23  18.95  0.63
# 1990-05-01 00:00:00   9.29  18.78  0.62
# 1990-05-02 00:00:00   9.31  18.97  0.64
# 1990-05-03 00:00:00   9.37  18.99  0.64
# 1990-05-04 00:00:00   9.37  19.43  0.67
# 1990-05-07 00:00:00   9.72  19.43  0.70
# 1990-05-08 00:00:00   9.78  19.47  0.68
# 1990-05-09 00:00:00   9.81  19.56  0.68
# 1990-05-10 00:00:00   9.70  19.75  0.70
# 1990-05-11 00:00:00   9.99  20.04  0.71
# 1990-05-14 00:00:00   9.78  20.09  0.72
# 1990-05-15 00:00:00   9.78  20.33  0.71
# ...

# %%
data.iloc[[10,20,30],4]
# Out:
# 1990-02-15 00:00:00    4.54
# 1990-03-02 00:00:00    4.43
# 1990-03-16 00:00:00    4.61
# Name: JNJ, dtype: float64

# %%
data.iloc[10:21,3:8]
# Out:
#                        IBM   JNJ  MSFT   PEP     SPX
# 1990-02-15 00:00:00  18.04  4.54  0.53  6.15  334.89
# 1990-02-16 00:00:00  17.99  4.47  0.53  6.11  332.72
# 1990-02-20 00:00:00  17.88  4.39  0.55  6.01  327.99
# 1990-02-21 00:00:00  18.23  4.33  0.52  5.91  327.67
# 1990-02-22 00:00:00  17.95  4.28  0.53  5.87  325.70
# 1990-02-23 00:00:00  17.84  4.20  0.53  5.88  324.15
# 1990-02-26 00:00:00  18.08  4.30  0.54  5.93  328.67
# 1990-02-27 00:00:00  18.04  4.30  0.53  6.00  330.26
# 1990-02-28 00:00:00  18.06  4.32  0.54  6.06  331.89
# 1990-03-01 00:00:00  18.08  4.35  0.55  5.98  332.74
# 1990-03-02 00:00:00  18.23  4.43  0.57  5.89  335.54

# %%
data
# Out:
#                         AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                    ...     ...    ...     ...    ...    ...    ...
# 2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#                          SPX    XOM
# 1990-02-01 00:00:00   328.79   6.12
# 1990-02-02 00:00:00   330.92   6.24
# ...

# %%
data.loc['1990-02-01 00:00:00','IBM']
# Out:
# 16.79

# %%
data.loc['1990-02-01 00:00:00':'1990-02-07 00:00:00','AAPL':'PEP']
# Out:
#                      AAPL    GE    IBM   JNJ  MSFT   PEP
# 1990-02-01 00:00:00  7.86  2.87  16.79  4.27  0.51  6.04
# 1990-02-02 00:00:00  8.00  2.87  16.89  4.37  0.51  6.09
# 1990-02-05 00:00:00  8.18  2.87  17.32  4.34  0.51  6.05
# 1990-02-06 00:00:00  8.12  2.88  17.56  4.32  0.51  6.15
# 1990-02-07 00:00:00  7.77  2.91  17.93  4.38  0.51  6.17

# %%
data.columns
# Out:
# Index(['AA', 'AAPL', 'GE', 'IBM', 'JNJ', 'MSFT', 'PEP', 'SPX', 'XOM'], dtype='object')

# %%
data.head()
# Out:
#                        AA  AAPL    GE    IBM   JNJ  MSFT   PEP     SPX   XOM
# 1990-02-01 00:00:00  4.98  7.86  2.87  16.79  4.27  0.51  6.04  328.79  6.12
# 1990-02-02 00:00:00  5.04  8.00  2.87  16.89  4.37  0.51  6.09  330.92  6.24
# 1990-02-05 00:00:00  5.07  8.18  2.87  17.32  4.34  0.51  6.05  331.85  6.25
# 1990-02-06 00:00:00  5.01  8.12  2.88  17.56  4.32  0.51  6.15  329.66  6.23
# 1990-02-07 00:00:00  5.04  7.77  2.91  17.93  4.38  0.51  6.17  333.75  6.33

# %%
data['AAPL'].unique()
# Out:
# array([  7.86,   8.  ,   8.18, ..., 402.19, 408.43, 422.  ])

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba\pandas_docs (1)
#
# 07/26/2023  09:42 AM    <DIR>          .
# 07/25/2023  09:14 PM    <DIR>          ..
# 07/25/2023  08:08 PM    <DIR>          .ipynb_checkpoints
# 07/26/2023  09:30 AM            71,378 ASSIGNMENT.ipynb
# 07/23/2023  05:31 PM               111 csv_mindex.csv
# 07/25/2023  09:34 AM           210,614 DATA ANALYSIS - WRK1.ipynb
# 07/24/2023  09:58 AM                87 data4new.csv
# 07/23/2023  05:31 PM                59 demo1.csv
# 07/23/2023  05:31 PM            10,545 demo1.xlsx
# 07/23/2023  05:31 PM                43 demo2.csv
# 07/23/2023  05:31 PM               169 demo3.csv
# 07/23/2023  05:31 PM               170 demo3.txt
# 07/23/2023  05:31 PM               169 demo4.csv
# 07/23/2023  05:31 PM                78 demo5.csv
# 07/23/2023  05:31 PM           626,863 demo6.csv
# 07/23/2023  05:31 PM                36 demo7.csv
# ...

# %%
survey=pd.read_csv('survey_results_public.csv')
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns',30)
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.min_rows',30)
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %% [markdown]
# ## data filtering

# %%
import pandas as pd

# %%
survey=pd.read_csv('survey_results_public.csv')
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey.loc[(survey['ConvertedComp']>300000) &  (survey['ConvertedComp']<1500000),['Gender','Country','ConvertedComp']]
# Out:
#       Gender         Country  ConvertedComp
# 5        Man          Canada       366420.0
# 15       Man  United Kingdom       455352.0
# 31       Man   United States      1100000.0
# 127      Man  United Kingdom      1000000.0
# 153      Man         Germany       962424.0
# ...      ...             ...            ...
# 88164    Man          Canada       732852.0
# 88204    Man     Switzerland      1000000.0
# 88314    Man        Portugal       412464.0
# 88315    Man         Germany       797436.0
# 88329    Man     Netherlands       588012.0
#
# [2833 rows x 3 columns]

# %%
import pandas as pd

# %%
survey=pd.read_csv('survey_results_public.csv')
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
fltr1=survey['LanguageWorkedWith'].str.contains('VBA',na=False)
fltr1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
filter2=survey.loc[fltr1,'LanguageWorkedWith']
filter2
# Out:
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 15       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 25       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 60           C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 61       Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;Jav...
#                                ...
# 88798                                             Java;VBA
# 88820    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88825                 Bash/Shell/PowerShell;Python;SQL;VBA
# 88833                                           C#;SQL;VBA
# 88866                            Assembly;C++;HTML/CSS;VBA
# Name: LanguageWorkedWith, Length: 4781, dtype: object

# %%
survey['WebFrameWorkedWith']
# Out:
# 0                                       Django;Flask
# 1                                             Django
# 2                                                NaN
# 3                                                NaN
# 4        Django;Express;Flask;jQuery;React.js;Spring
#                             ...
# 88878                                         jQuery
# 88879                                            NaN
# 88880                                            NaN
# 88881                                            NaN
# 88882                         Django;jQuery;React.js
# Name: WebFrameWorkedWith, Length: 88883, dtype: object

# %%
flask=survey['WebFrameWorkedWith'].str.contains('Flask',na=False)
flask
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: WebFrameWorkedWith, Length: 88883, dtype: bool

# %%
pd.options.display.max_colwidth=100

# %%
survey.loc[flask,'WebFrameWorkedWith']
# Out:
# 0                                                                                               Django;Flask
# 4                                                                Django;Express;Flask;jQuery;React.js;Spring
# 7                                                                              Express;Flask;React.js;Spring
# 9                                                     Angular/Angular.js;ASP.NET;Django;Express;Flask;jQuery
# 20                                                                                    Django;Flask;Other(s):
#                                                         ...
# 88804                                                                                 Express;Flask;React.js
# 88820    Angular/Angular.js;ASP.NET;Django;Drupal;Express;Flask;jQuery;Laravel;React.js;Ruby on Rails;Spr...
# 88826                                                                                    Django;Flask;jQuery
# ...
