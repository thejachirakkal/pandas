# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# df.loc[df['ConvertedComp'] > 1900000,'ConvertedComp'] = 1900000

# %%
df.loc[df['ConvertedComp']> 1900000,"ConvertedComp"] = 190000

# %%
df2 = df[df['ConvertedComp'] > 1900000]
df2
# Out:
# Empty DataFrame
# ...

# %%
df['ConvertedComp'].max()
# Out:
# 1872000.0

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df[df['ConvertedComp']>1900000]
# Out:
# Empty DataFrame
# ...

# %%
df2=df.copy()

# %% [markdown]
# ### Aggregates

# %% [markdown]
# Aggregation means we are using multiple data to get a single metric/a single value to represents multiple data(Mean,Median,Mode)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['ConvertedComp'].head()
# Out:
# 0        NaN
# 1        NaN
# 2     8820.0
# 3    61000.0
# 4        NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].nlargest(100)
# Out:
# 31793    1872000.0
# 16764    1860000.0
# 36107    1860000.0
# 68427    1860000.0
# 68865    1860000.0
#            ...
# 50746    1584000.0
# 60676    1584000.0
# 83650    1572000.0
# 2751     1560000.0
# 4727     1560000.0
# Name: ConvertedComp, Length: 100, dtype: float64

# %%
df['ConvertedComp'].nsmallest(10)
# Out:
# 278     0.0
# 291     0.0
# 719     0.0
# 1101    0.0
# 1494    0.0
# 1678    0.0
# 1774    0.0
# 2011    0.0
# 2087    0.0
# 2656    0.0
# Name: ConvertedComp, dtype: float64

# %%
df2.nlargest(10,"ConvertedComp")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 31793       31984                     I am a developer by profession      Yes
# 16764       16855                     I am a developer by profession      Yes
# 36107       36331                     I am a developer by profession      Yes
# 68427       68865  I am not primarily a developer, but I write co...      Yes
# 68865       69305                     I am a developer by profession      Yes
# 85379       85911                     I am a developer by profession      Yes
# 18633       18736                     I am a developer by profession       No
# 12061       12117  I am not primarily a developer, but I write co...      Yes
# 23138       23267                     I am a developer by profession      Yes
# 18030       18131                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
df2.nsmallest(10,"ConvertedComp")
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 278          280  I am a developer by profession      Yes
# 291          293  I am a developer by profession      Yes
# 719          722  I am a developer by profession       No
# 1101        1105  I am a developer by profession       No
# 1494        1501  I am a developer by profession      Yes
# 1678        1685  I am a developer by profession      Yes
# 1774        1782  I am a developer by profession      Yes
# 2011        2019  I am a developer by profession       No
# 2087        2095  I am a developer by profession      Yes
# 2656        2665  I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 278                             Less than once per year
# 291                             Less than once per year
# 719   Less than once a month but more than once per ...
# 1101                                              Never
# ...

# %%
df2 = df.loc[100:200,:]

# %%
df2['ConvertedComp'].nlargest()
# Out:
# 127    1000000.0
# 153     962424.0
# 155     960000.0
# 130     199450.0
# 124     194800.0
# Name: ConvertedComp, dtype: float64

# %%
df2['ConvertedComp'].nsmallest()
# Out:
# 167     979.0
# 172    2016.0
# 103    2169.0
# 176    2500.0
# 138    7556.0
# Name: ConvertedComp, dtype: float64

# %%
df2['ConvertedComp'].max()
# Out:
# 1000000.0

# %%
df['ConvertedComp'].min()
# Out:
# 0.0

# %%
df2.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
# df2['Sexuality'].max()

# %%
df2['ConvertedComp'].sum()
# Out:
# 7670801.0

# %%
df2['ConvertedComp'].mean()
# Out:
# 103659.47297297297

# %%
df2['ConvertedComp'].median()
# Out:
# 57498.0

# %%
df2['ConvertedComp'].mode()
# Out:
# 0    54996.0
# 1    65424.0
# Name: ConvertedComp, dtype: float64

# %%
df2['ConvertedComp'].std()
# Out:
# 186953.60791634273

# %%
df2['ConvertedComp'].var()
# Out:
# 34951651512.93761

# %%
df2.describe()
# Out:
#        Respondent     CompTotal   ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# count  101.000000  7.400000e+01       74.000000    82.000000   70.000000
# mean   151.633663  1.837439e+06   103659.472973    46.829268    4.892857
# std     29.705462  1.057886e+07   186953.607916    41.235190    4.340484
# min    101.000000  5.000000e+01      979.000000     6.000000    0.000000
# 25%    126.000000  1.500000e+04    35704.750000    40.000000    2.000000
# 50%    152.000000  6.100000e+04    57498.000000    40.000000    4.000000
# 75%    177.000000  1.060000e+05    92963.250000    45.000000    6.000000
# max    202.000000  8.500000e+07  1000000.000000   385.000000   20.000000
#
#              Age
# count  88.000000
# mean   32.159091
# std     8.826405
# min    18.000000
# 25%    26.000000
# 50%    30.000000
# 75%    36.000000
# max    64.000000

# %%
df2.describe(include="all")
# Out:
#         Respondent                      MainBranch Hobbyist OpenSourcer  \
# count   101.000000                             101      101         101
# unique         NaN                               5        2           4
# top            NaN  I am a developer by profession      Yes       Never
# freq           NaN                              83       83          35
# mean    151.633663                             NaN      NaN         NaN
# std      29.705462                             NaN      NaN         NaN
# min     101.000000                             NaN      NaN         NaN
# 25%     126.000000                             NaN      NaN         NaN
# 50%     152.000000                             NaN      NaN         NaN
# 75%     177.000000                             NaN      NaN         NaN
# max     202.000000                             NaN      NaN         NaN
#
#                                                OpenSource          Employment  \
# ...

# %%
df2['Hobbyist'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df2['Hobbyist'].nunique()
# Out:
# 2

# %%
df2['Hobbyist'].value_counts()#frequency distribution of each distinct values
# Out:
# Yes    83
# No     18
# Name: Hobbyist, dtype: int64

# %%
df2['Hobbyist'].value_counts(normalize=True)#percentage total of frequency distribution
# Out:
# Yes    0.821782
# No     0.178218
# Name: Hobbyist, dtype: float64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema.loc['SocialMedia',"QuestionText"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 schema.loc['SocialMedia',"QuestionText"]
#
# NameError: name 'schema' is not defined

# %%
schema.set_index("Column",inplace=True)

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['SocialMedia'].value_counts()/df.shape[0] * 100
# Out:
# Reddit                      16.171821
# YouTube                     15.559781
# WhatsApp                    15.016370
# Facebook                    14.826232
# Twitter                     12.823600
# Instagram                    7.044092
# I don't use social media     6.248664
# LinkedIn                     5.063960
# WeChat 微信                    0.750425
# Snapchat                     0.706547
# VK ВКонта́кте                0.678420
# Weibo 新浪微博                   0.063004
# Youku Tudou 优酷               0.023627
# Hello                        0.021376
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ## Group By

# %% [markdown]
# - It uses to get any aggregated values for all the features/particular features(Avg salary of developer, number of indian developers who knows python)

# %% [markdown]
# ## Split > Apply Func > Combine Results

# %%
filt1 = df['Country']=="India"
df[filt1]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt2 = df['Country']=="United States"

# %%
df[filt2]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
pd.set_option('display.min_rows',50)

# %%
df['Country'].value_counts()
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# ...

# %%
country_group = df.groupby('Country')

# %%
country_group

# %%
country_group.get_group("India")
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# 67             68          I am a developer by profession      Yes
# 74             75          I am a developer by profession      Yes
# 77             78          I am a developer by profession       No
# 82             83          I am a developer by profession      Yes
# 88             89  I am a student who is learning to code      Yes
# 89             90          I am a developer by profession      Yes
# 98             99  I am a student who is learning to code      Yes
# 103           104          I am a developer by profession      Yes
# ...

# %%
country_group.get_group("United States")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3               4                     I am a developer by profession       No
# 12             13                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# 22             23                     I am a developer by profession      Yes
# 25             26                     I am a developer by profession      Yes
# 28             29                     I am a developer by profession      Yes
# 31             32                     I am a developer by profession       No
# 34             35                     I am a developer by profession       No
# 38             39                     I am a developer by profession      Yes
# 44             45  I am not primarily a developer, but I write co...      Yes
# 45             46                     I am a developer by profession      Yes
# ...

# %%
gender_group  = df.groupby("Gender")

# %%
gender_group.get_group('Woman')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 11             12             I am a student who is learning to code       No
# 30             31             I am a student who is learning to code       No
# 34             35                     I am a developer by profession       No
# 50             51             I am a student who is learning to code      Yes
# 70             71                     I am a developer by profession      Yes
# 74             75                     I am a developer by profession      Yes
# 85             86  I am not primarily a developer, but I write co...      Yes
# 99            100                     I am a developer by profession      Yes
# 104           105                     I am a developer by profession      Yes
# 140           142                     I am a developer by profession       No
# 146           148                     I am a developer by profession      Yes
# ...

# %%
gender_group.get_group('Man')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# 12             13                     I am a developer by profession      Yes
# ...

# %%
country_group.get_group('Germany')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 13             14                     I am a developer by profession      Yes
# 35             36                     I am a developer by profession      Yes
# 43             44                     I am a developer by profession      Yes
# 65             66                     I am a developer by profession      Yes
# 84             85                     I am a developer by profession      Yes
# 92             93  I am not primarily a developer, but I write co...       No
# 141           143                     I am a developer by profession      Yes
# 142           144                     I am a developer by profession       No
# 153           155                     I am a developer by profession      Yes
# 171           173                     I am a developer by profession      Yes
# 198           200                     I am a developer by profession       No
# ...

# %%
country_group.get_group(['Germany','India'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 country_group.get_group(['Germany','India'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:815, in BaseGroupBy.get_group(self, name, obj)
#     812 if obj is None:
#     813     obj = self._selected_obj
# --> 815 inds = self._get_index(name)
#     816 if not len(inds):
#     817     raise KeyError(name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:743, in BaseGroupBy._get_index(self, name)
#     738 @final
#     739 def _get_index(self, name):
#     740     """
#     741     Safe get index, translate keys for datelike to underlying repr.
#     742     """
# --> 743     return self._get_indices([name])[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:736, in BaseGroupBy._get_indices(self, names)
# ...

# %%
filt3 = df['Country']=="India"

# %%
# df.columns

# %%
df.loc[filt3]["SocialMedia"].value_counts()

# %%
country_group['SocialMedia'].value_counts().head(50)

# %%
country_group['SocialMedia'].value_counts().loc['India']

# %%
social_group=country_group['SocialMedia']

# %%
social_group.get_group('India').value_counts(normalize=True)
# Out:
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_group['SocialMedia'].value_counts().loc['France']
# Out:
# SocialMedia
# Twitter                     479
# YouTube                     387
# Facebook                    358
# Reddit                      358
# WhatsApp                    228
# I don't use social media    205
# LinkedIn                    139
# Instagram                   101
# Snapchat                     12
# WeChat 微信                    12
# VK ВКонта́кте                 1
# Youku Tudou 优酷                1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Germany']
# Out:
# SocialMedia
# WhatsApp                    1343
# YouTube                      970
# Reddit                       923
# Twitter                      866
# I don't use social media     501
# Facebook                     404
# Instagram                    264
# LinkedIn                     141
# Snapchat                      10
# VK ВКонта́кте                  8
# WeChat 微信                      8
# Name: SocialMedia, dtype: int64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Employment'].unique()
# Out:
# array(['Not employed, and not looking for work',
#        'Not employed, but looking for work', 'Employed full-time',
#        'Independent contractor, freelancer, or self-employed', nan,
#        'Employed part-time', 'Retired'], dtype=object)

# %% [raw]
# - i want to retrieve all the emplyment type details by country
#     - Distributions of different employment type in each country
# Pakistan,Afghanistan,Nepal,India,Maldives,Bhutan,Bangladesh,Sri Lanka
#
#
#
# - percentage of retired people in different countries
# Pakistan,Afghanistan,Nepal,India,Maldives,Bhutan,Bangladesh,Sri Lanka,United States

# %%
country_group['ConvertedComp'].mean()#it will retunr mean salary inside each country
# Out:
# Country
# Afghanistan                                  101953.333333
# Albania                                       21833.700000
# Algeria                                       34924.047619
# Andorra                                      160931.000000
# Angola                                         7764.000000
# Antigua and Barbuda                                    NaN
# Argentina                                     29467.265306
# Armenia                                       24691.733333
# Australia                                    171541.116279
# Austria                                       83955.639604
# Azerbaijan                                    15785.750000
# Bahamas                                                NaN
# Bahrain                                       23934.000000
# Bangladesh                                    21249.652000
# Barbados                                      21000.000000
# Belarus                                       29442.330645
# ...

# %%
country_group['ConvertedComp'].mean().loc["United States"]
# Out:
# 164159.72498498097

# %%
country_group['ConvertedComp'].mean().loc["Germany"]
# Out:
# 108777.79460031763

# %%
country_group['ConvertedComp'].median().loc["Sri Lanka"]
# Out:
# 7476.0

# %%
country_group['ConvertedComp'].describe()
# Out:
#                                              count           mean  \
# Country
# Afghanistan                                   12.0  101953.333333
# Albania                                       50.0   21833.700000
# Algeria                                       42.0   34924.047619
# Andorra                                        2.0  160931.000000
# Angola                                         1.0    7764.000000
# Antigua and Barbuda                            0.0            NaN
# Argentina                                    392.0   29467.265306
# Armenia                                       45.0   24691.733333
# Australia                                   1247.0  171541.116279
# Austria                                      505.0   83955.639604
# Azerbaijan                                    24.0   15785.750000
# Bahamas                                        0.0            NaN
# Bahrain                                       10.0   23934.000000
# ...

# %%
country_group['ConvertedComp'].agg(['mean','median','min','max'])
# Out:
#                                                     mean    median       min  \
# Country
# Afghanistan                                101953.333333    6222.0       0.0
# Albania                                     21833.700000   10818.0    1320.0
# Algeria                                     34924.047619    7878.0       0.0
# Andorra                                    160931.000000  160931.0  150000.0
# Angola                                       7764.000000    7764.0    7764.0
# Antigua and Barbuda                                  NaN       NaN       NaN
# Argentina                                   29467.265306   17760.0      12.0
# Armenia                                     24691.733333   19692.0       0.0
# Australia                                  171541.116279   79783.0       0.0
# Austria                                     83955.639604   51559.0       0.0
# Azerbaijan                                  15785.750000   15858.0    3750.0
# ...

# %% [markdown]
# ### Try to Explore argmax and argmin

# %%
country_group['ConvertedComp'].agg(['mean','median','min','max']).loc['India']
# Out:
# mean        26699.825456
# median      10080.000000
# min             0.000000
# max       1000000.000000
# Name: India, dtype: float64

# %%
country_group['ConvertedComp'].agg(['mean','median',"min"]).loc['India']
# Out:
# mean      26699.825456
# median    10080.000000
# min           0.000000
# Name: India, dtype: float64

# %% [markdown]
# ## Try another problem

# %% [markdown]
# ## Get developer who use python by country

# %%
filt3 = df['Country']=='India'

# %%
df[filt3]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# 67             68          I am a developer by profession      Yes
# 74             75          I am a developer by profession      Yes
# 77             78          I am a developer by profession       No
# 82             83          I am a developer by profession      Yes
# 88             89  I am a student who is learning to code      Yes
# 89             90          I am a developer by profession      Yes
# 98             99  I am a student who is learning to code      Yes
# 103           104          I am a developer by profession      Yes
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                               Java;R;SQL
# 6                                      HTML/CSS;JavaScript
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9                            C#;Go;JavaScript;Python;R;SQL
# 10                                               Other(s):
# 11        Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 12       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 13                                                     C++
# 14       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 15       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# ...

# %%
df['LanguageWorkedWith'].str.contains('Python').sum()#these many number of developers are using python
# Out:
# 36443

# %%
df.loc[filt3]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
# country_group['LanguageWorkedWith'].get_group("India").str.contains('Python').sum()

# %%
country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum()).loc['India']
# Out:
# 3105

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                                      8
# Albania                                         23
# Algeria                                         40
# Andorra                                          0
# Angola                                           2
# Antigua and Barbuda                              0
# Argentina                                      191
# Armenia                                         28
# Australia                                      790
# Austria                                        338
# Azerbaijan                                      17
# Bahamas                                          2
# Bahrain                                          4
# Bangladesh                                     204
# Barbados                                         1
# Belarus                                         69
# Belgium                                        296
# Belize                                           1
# ...

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# ...

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis='columns')
python_df
# Out:
#                                        Country  LanguageWorkedWith
# United States                            20949               10083
# India                                     9061                3105
# Germany                                   5866                2451
# United Kingdom                            5737                2384
# Canada                                    3395                1558
# France                                    2391                1054
# Brazil                                    1948                 767
# Poland                                    1922                 751
# Australia                                 1903                 790
# Netherlands                               1852                 767
# Russian Federation                        1694                 708
# Spain                                     1604                 641
# Italy                                     1576                 625
# ...

# %%
python_df.rename(columns={"Country":"NumofRespondents","LanguageWorkedWith":"NumKnowsPython"},inplace=True)

# %%
python_df['PctKnowsPython'] = round((python_df['NumKnowsPython']/python_df['NumofRespondents']) * 100,2)

# %%
python_df = python_df.drop('PctofRespondents',axis=1)

# %%
python_df
# Out:
#                                        NumofRespondents  NumKnowsPython  \
# United States                                     20949           10083
# India                                              9061            3105
# Germany                                            5866            2451
# United Kingdom                                     5737            2384
# Canada                                             3395            1558
# France                                             2391            1054
# Brazil                                             1948             767
# Poland                                             1922             751
# Australia                                          1903             790
# Netherlands                                        1852             767
# Russian Federation                                 1694             708
# Spain                                              1604             641
# ...

# %%
python_df['PctKnowsPython'].argmax()
# Out:
# 169

# %%
python_df.iloc[python_df['PctKnowsPython'].argmax()]
# Out:
# NumofRespondents      1.0
# NumKnowsPython        1.0
# PctKnowsPython      100.0
# Name: Sao Tome and Principe, dtype: float64

# %% [markdown]
# > Experiment with argmax and percentage of python users(try different thresholds)

# %%
python_df.sort_values('PctKnowsPython',ascending=False,inplace=True)

# %%
python_df
# Out:
#                                            NumofRespondents  NumKnowsPython  \
# Sao Tome and Principe                                     1               1
# Timor-Leste                                               1               1
# Dominica                                                  1               1
# Niger                                                     1               1
# Turkmenistan                                              7               6
# Mauritania                                                7               5
# Guinea                                                    3               2
# Bahamas                                                   3               2
# Guyana                                                    3               2
# Uganda                                                   72              47
# Iceland                                                  49              30
# ...

# %%
python_df.loc['Japan']
# Out:
# NumofRespondents    391.00
# NumKnowsPython      182.00
# PctKnowsPython       46.55
# Name: Japan, dtype: float64

# %%
python_df.loc['France']
# Out:
# NumofRespondents    2391.00
# NumKnowsPython      1054.00
# PctKnowsPython        44.08
# Name: France, dtype: float64

# %%
python_df.loc['Maldives']
# Out:
# NumofRespondents    13.00
# NumKnowsPython       6.00
# PctKnowsPython      46.15
# Name: Maldives, dtype: float64

# %%
python_df.loc['Norway']
# Out:
# NumofRespondents    574.00
# NumKnowsPython      232.00
# PctKnowsPython       40.42
# Name: Norway, dtype: float64

# %%
python_df[(python_df['PctKnowsPython']>50) & (python_df['PctKnowsPython']!=100)]
# Out:
#                            NumofRespondents  NumKnowsPython  PctKnowsPython
# Turkmenistan                              7               6           85.71
# Mauritania                                7               5           71.43
# Guinea                                    3               2           66.67
# Bahamas                                   3               2           66.67
# Guyana                                    3               2           66.67
# Uganda                                   72              47           65.28
# Iceland                                  49              30           61.22
# Haiti                                     5               3           60.00
# Benin                                     5               3           60.00
# Namibia                                   5               3           60.00
# Congo, Republic of the...                 7               4           57.14
# ...

# %%
python_df[(python_df['PctKnowsPython']>50) & (python_df['NumofRespondents'] > 50)]
# Out:
#         NumofRespondents  NumKnowsPython  PctKnowsPython
# Uganda                72              47           65.28

# %%
house = pd.read_csv('housing.csv')
house.head()#block data
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
house = house.dropna()

# %%
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
house.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
house['rooms_per_hh'] = house['total_rooms']/house['households']
house['bedrooms_per_room'] = house['total_bedrooms']/house['total_rooms']
house['population_per_hh'] = house['population']/house['households']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8052\116068079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['rooms_per_hh'] = house['total_rooms']/house['households']
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8052\116068079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['bedrooms_per_room'] = house['total_bedrooms']/house['total_rooms']
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8052\116068079.py:3: SettingWithCopyWarning:
# ...

# %%
house.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
#
#    rooms_per_hh  bedrooms_per_room  population_per_hh
# 0      6.984127           0.146591           2.555556
# 1      6.238137           0.155797           2.109842

# %% [markdown]
# ### Making df togather

# %%
import pandas as pd

# %%
data1=pd.DataFrame({"Roll No.":[101,103,104,107,106],"Gender":['M','F','F','M','M'],"Name":['Rob','Pam','Max','Tom','Ben']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data1=pd.DataFrame({"Roll No.":[101,103,104,107,106],"Gender":['M','F','F','M','M'],"Name":['Rob','Pam','Max','Tom','Ben']})
#
# NameError: name 'pd' is not defined

# %%
data1
# Out:
#    Roll No. Gender Name
# 0       101      M  Rob
# 1       103      F  Pam
# 2       104      F  Max
# 3       107      M  Tom
# 4       106      M  Ben

# %%
data2=pd.DataFrame({"Roll No.":[101,102,103,104,105,111],"Age":[31,35,36,30,38,56] })

# %%
data2
# Out:
#    Roll No.  Age
# 0       101   31
# 1       102   35
# 2       103   36
# 3       104   30
# 4       105   38

# %%
df_merge = pd.merge(left=data2,right=data1,how='inner')
df_merge
# Out:
#    Roll No.  Age Gender Name
# 0       101   31      M  Rob
# 1       103   36      F  Pam
# 2       104   30      F  Max

# %%
data1
# Out:
#    Roll No. Gender Name
# 0       101      M  Rob
# 1       103      F  Pam
# 2       104      F  Max
# 3       107      M  Tom
# 4       106      M  Ben

# %%
data2
# Out:
#    Roll No.  Age
# 0       101   31
# 1       102   35
# 2       103   36
# 3       104   30
# 4       105   38

# %%
df_all = data2.join(data1,lsuffix="_new",rsuffix="_old")
df_all
# Out:
#    Roll No._new  Age  Roll No._old Gender Name
# 0           101   31         101.0      M  Rob
# 1           102   35         103.0      F  Pam
# 2           103   36         104.0      F  Max
# 3           104   30         107.0      M  Tom
# 4           105   38         106.0      M  Ben
# 5           111   56           NaN    NaN  NaN

# %%
import pandas as pd
  
# Creating dataframe a
a = pd.DataFrame()
  
# Creating Dictionary
d = {'id': [1, 2, 10, 12], 
     'val1': ['a', 'b', 'c', 'd']}
  
a = pd.DataFrame(d)
  
# printing the dataframe
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
import pandas as pd

# DataFrame 1
data1 = {
    'ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 22, 28]
}

df1 = pd.DataFrame(data1)

# DataFrame 2
data2 = {
    'ID': [2, 3, 4, 5],
    'City': ['New York', 'San Francisco', 'Boston', 'Chicago'],
    'Salary': [60000, 75000, 50000, 80000]
}

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   22
# 3   4    David   28

# %%
df2
# Out:
#    ID           City  Salary
# 0   2       New York   60000
# 1   3  San Francisco   75000
# 2   4         Boston   50000
# 3   5        Chicago   80000

# %%
result_concat = pd.concat([df1, df2], ignore_index=True)
result_concat
# Out:
#    ID     Name   Age           City   Salary
# 0   1    Alice  25.0            NaN      NaN
# 1   2      Bob  30.0            NaN      NaN
# 2   3  Charlie  22.0            NaN      NaN
# 3   4    David  28.0            NaN      NaN
# 4   2      NaN   NaN       New York  60000.0
# 5   3      NaN   NaN  San Francisco  75000.0
# 6   4      NaN   NaN         Boston  50000.0
# 7   5      NaN   NaN        Chicago  80000.0

# %%
result_inner = pd.merge(df1,df2,on="ID",how="inner")
result_inner
# Out:
#    ID     Name  Age           City  Salary
# 0   2      Bob   30       New York   60000
# 1   3  Charlie   22  San Francisco   75000
# 2   4    David   28         Boston   50000

# %%
df1.append(df2,ignore_index=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8052\2717680053.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2,ignore_index=True)
#    ID     Name   Age           City   Salary
# 0   1    Alice  25.0            NaN      NaN
# 1   2      Bob  30.0            NaN      NaN
# 2   3  Charlie  22.0            NaN      NaN
# 3   4    David  28.0            NaN      NaN
# 4   2      NaN   NaN       New York  60000.0
# 5   3      NaN   NaN  San Francisco  75000.0
# 6   4      NaN   NaN         Boston  50000.0
# 7   5      NaN   NaN        Chicago  80000.0

# %%
result_inner = pd.merge(df1,df2,on="ID",how="inner")
result_inner
# Out:
#    ID     Name  Age           City  Salary
# 0   2      Bob   30       New York   60000
# 1   3  Charlie   22  San Francisco   75000
# 2   4    David   28         Boston   50000

# %%
result_ordered = pd.merge_ordered(df1,df2,on='ID')
result_ordered
# Out:
#    ID     Name   Age           City   Salary
# 0   1    Alice  25.0            NaN      NaN
# 1   2      Bob  30.0       New York  60000.0
# 2   3  Charlie  22.0  San Francisco  75000.0
# 3   4    David  28.0         Boston  50000.0
# 4   5      NaN   NaN        Chicago  80000.0

# %%
df1
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   22
# 3   4    David   28

# %%
df2
# Out:
#    ID           City  Salary
# 0   2       New York   60000
# 1   3  San Francisco   75000
# 2   4         Boston   50000
# 3   5        Chicago   80000

# %%
result_asof =pd.merge_asof(df2,df1,on="ID")
result_asof
# Out:
#    ID           City  Salary     Name  Age
# 0   2       New York   60000      Bob   30
# 1   3  San Francisco   75000  Charlie   22
# 2   4         Boston   50000    David   28
# 3   5        Chicago   80000    David   28

# %%
import pandas as pd

data1 = {'Timestamp': ['2023-07-01 10:00:00', '2023-07-03 15:30:00', '2023-07-05 08:45:00'],
         'Value1': [10, 15, 20]}

data2 = {'Timestamp': ['2023-07-02 09:00:00', '2023-07-04 14:00:00'],
         'Value2': [5, 25]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# %%
df2.dtypes
# Out:
# Timestamp    datetime64[ns]
# Value2                int64
# dtype: object

# %%
df1
# Out:
#             Timestamp  Value1
# 0 2023-07-01 10:00:00      10
# 1 2023-07-03 15:30:00      15
# 2 2023-07-05 08:45:00      20

# %%
df2
# Out:
#             Timestamp  Value2
# 0 2023-07-02 09:00:00       5
# 1 2023-07-04 14:00:00      25

# %%
merged_Df = pd.merge_asof(df1,df2,on="Timestamp",direction="backward")
merged_Df
# Out:
#             Timestamp  Value1  Value2
# 0 2023-07-01 10:00:00      10     NaN
# 1 2023-07-03 15:30:00      15     5.0
# 2 2023-07-05 08:45:00      20    25.0

# %%
merged_Df = pd.merge_asof(df2,df1,on="Timestamp")
merged_Df
# Out:
#             Timestamp  Value2  Value1
# 0 2023-07-02 09:00:00       5      10
# 1 2023-07-04 14:00:00      25      15

# %%
merged_Df = pd.merge_asof(df1,df2,on="Timestamp",direction="forward")
merged_Df
# Out:
#             Timestamp  Value1  Value2
# 0 2023-07-01 10:00:00      10     5.0
# 1 2023-07-03 15:30:00      15    25.0
# 2 2023-07-05 08:45:00      20     NaN

# %%
df1
# Out:
#             Timestamp  Value1
# 0 2023-07-01 10:00:00      10
# 1 2023-07-03 15:30:00      15
# 2 2023-07-05 08:45:00      20

# %%
import pandas as pd

# DataFrame 1
data1 = {'Timestamp': ['2023-07-01 10:00:00', '2023-07-03 15:30:00', '2023-07-05 08:45:00'],
         'Value1': [10, 15, 20]}
df1 = pd.DataFrame(data1)

# DataFrame 2
data2 = {'Timestamp': ['2023-07-02 09:00:00', '2023-07-04 14:00:00'],
         'Value2': [5, 25]}
df2 = pd.DataFrame(data2)

# %%
df1.dtypes
# Out:
# Timestamp    object
# Value1        int64
# dtype: object

# %%
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# %%
df1
# Out:
#             Timestamp  Value1
# 0 2023-07-01 10:00:00      10
# 1 2023-07-03 15:30:00      15
# 2 2023-07-05 08:45:00      20

# %%
df2
# Out:
#             Timestamp  Value2
# 0 2023-07-02 09:00:00       5
# 1 2023-07-04 14:00:00      25

# %%
pd.merge_asof(df1,df2,on="Timestamp",direction="forward")
# Out:
#             Timestamp  Value1  Value2
# 0 2023-07-01 10:00:00      10     5.0
# 1 2023-07-03 15:30:00      15    25.0
# 2 2023-07-05 08:45:00      20     NaN

# %%
import pandas as pd

data = {
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Major': ['Math', 'English', 'Math', 'Math', 'English'],
    'Score': [85, 78, 92, 88, 95]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Gender    Major  Score
# 0    Male     Math     85
# 1  Female  English     78
# 2    Male     Math     92
# 3  Female     Math     88
# 4    Male  English     95

# %%
df[df['Gender']=="Female"]
# Out:
#    Gender    Major  Score
# 1  Female  English     78
# 3  Female     Math     88

# %%
df[df['Gender']=="Male"]
# Out:
#   Gender    Major  Score
# 0   Male     Math     85
# 2   Male     Math     92
# 4   Male  English     95

# %%
(85+92)/2
# Out:
# 88.5

# %%
cross_tab = pd.crosstab(df['Gender'],df['Major'],values=df['Score'],aggfunc='mean')
cross_tab
# Out:
# Major   English  Math
# Gender
# Female     78.0  88.0
# Male       95.0  88.5

# %% [markdown]
# - Value counts of Gender wise by Country
# - Gender wise Python Users in each country
# - Groupby EdLevel, Salary Median
# - Years of experience grouping> Salary in terms of Years of Experience(median)
# - Years of experience grouping> Count of Gender
# - Country wise grouping>> Retreieve how much blockchain tech is famous/implemented in organizations

# %%
df_new=house[20000:]

# %%
df_new.ocean_proximity.unique()
# Out:
# array(['NEAR OCEAN', '<1H OCEAN', 'INLAND'], dtype=object)

# %%
df_new.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'rooms_per_hh',
#        'bedrooms_per_room', 'population_per_hh'],
#       dtype='object')

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Language': ['Python', 'Python', 'Java', 'Python', 'Java'],
    'Experience': ['Beginner', 'Intermediate', 'Advanced', 'Intermediate', 'Beginner']
}

df = pd.DataFrame(data)

# %%
df_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20202    -119.20     34.26                25.0       2203.0           367.0
# 20203    -119.20     34.25                18.0       3208.0           643.0
# 20204    -119.20     34.25                25.0        195.0            59.0
# 20205    -119.20     34.28                22.0       2362.0           601.0
# 20206    -119.22     34.27                30.0       1937.0           295.0
# 20207    -119.23     34.27                22.0       3536.0           615.0
# 20208    -119.21     34.31                22.0       7548.0          1038.0
# 20209    -119.21     34.28                27.0       2219.0           312.0
# 20210    -119.23     34.30                18.0       1713.0           244.0
# 20211    -119.23     34.28                24.0       4260.0           691.0
# 20212    -119.22     34.28                24.0       2212.0           332.0
# ...

# %%
df
# Out:
#       Name Language    Experience
# 0    Alice   Python      Beginner
# 1      Bob   Python  Intermediate
# 2  Charlie     Java      Advanced
# 3    David   Python  Intermediate
# 4      Eve     Java      Beginner

# %%
pd.crosstab(df['Experience'],df['Language'])
# Out:
# Language      Java  Python
# Experience
# Advanced         1       0
# Beginner         1       1
# Intermediate     0       2

# %%
pd.crosstab(df_new['ocean_proximity'],df_new['housing_median_age'])
# Out:
# housing_median_age  3.0   4.0   5.0   6.0   7.0   8.0   9.0   10.0  11.0  \
# ocean_proximity
# <1H OCEAN              1     2     5     5     1     1     2     3     6
# INLAND                 0     0     2     2     1     1     1     3     5
# NEAR OCEAN             0     1     1     0     0     2     1     0     0
#
# housing_median_age  12.0  ...  41.0  42.0  43.0  44.0  45.0  46.0  47.0  48.0  \
# ocean_proximity           ...
# <1H OCEAN              1  ...     0     1     0     0     1     0     1     0
# INLAND                 2  ...     1     2     4     0     1     0     1     1
# NEAR OCEAN             3  ...     4     2     1     2     0     2     0     0
#
# housing_median_age  50.0  52.0
# ocean_proximity
# <1H OCEAN              1     0
# INLAND                 0     1
# NEAR OCEAN             2     3
#
# [3 rows x 48 columns]

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
pd.crosstab(df['Gender'],df['Hobbyist'])
# Out:
# Hobbyist                                               No    Yes
# Gender
# Man                                                 14300  63619
# Man;Non-binary, genderqueer, or gender non-conf...     28    153
# Non-binary, genderqueer, or gender non-conforming     119    478
# Woman                                                2318   4026
# Woman;Man                                              22    110
# Woman;Man;Non-binary, genderqueer, or gender no...     15     55
# Woman;Non-binary, genderqueer, or gender non-co...     32    131

# %%
import pandas as pd

# %%
dummy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Feature1': ['A', 'C', 'E', 'G', 'I'],
        'Feature2': ['B', 'D', 'F', 'H', 'J']}

df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2'])

df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
dummy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Feature1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature2': ['L', 'N', 'P', 'R', 'T']}
df2 = pd.DataFrame(dummy_data2, columns = ['id', 'Feature1', 'Feature2'])

df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
dummy_data3 = {
        'id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'Feature3': [12, 13, 14, 15, 16, 17, 15, 12, 13, 23]}
df3 = pd.DataFrame(dummy_data3, columns = ['id', 'Feature3'])

df3
# Out:
#    id  Feature3
# 0   1        12
# 1   2        13
# 2   3        14
# 3   4        15
# 4   5        16
# 5   7        17
# 6   8        15
# 7   9        12
# 8  10        13
# 9  11        23

# %% [markdown]
# ## concatenation

# %%
df_row = pd.concat([df1,df2],ignore_index=True)
df_row
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 5  1        K        L
# 6  2        M        N
# 7  6        O        P
# 8  7        Q        R
# 9  8        S        T

# %% [markdown]
# ## Merge

# %%
df_merge_col = pd.merge(df_row,df3,on='id')
df_merge_col
# Out:
#   id  Feature3 Feature1 Feature2
# 0  1        12        A        B
# 1  1        12        K        L
# 2  2        13        C        D
# 3  2        13        M        N
# 4  3        14        E        F
# 5  4        15        G        H
# 6  5        16        I        J
# 7  7        17        Q        R
# 8  8        15        S        T

# %% [markdown]
# You can notice that the DataFrames are now merged into a single DataFrame based on the **common values** present in the **id** column of both the DataFrames.

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
df_merge_difkey = pd.merge(df_row,df3,left_on="id",right_on="id")
df_merge_difkey
# Out:
#   id Feature1 Feature2  Feature3
# 0  1        A        B        12
# 1  1        K        L        12
# 2  2        C        D        13
# 3  2        M        N        13
# 4  3        E        F        14
# 5  4        G        H        15
# 6  5        I        J        16
# 7  7        Q        R        17
# 8  8        S        T        15

# %%
df4 = df3.copy()

# %%
df4.rename(columns={"id":"customer_id"},inplace=True)

# %%
df4
# Out:
#   customer_id  Feature3
# 0           1        12
# 1           2        13
# 2           3        14
# 3           4        15
# 4           5        16
# 5           7        17
# 6           8        15
# 7           9        12
# 8          10        13
# 9          11        23

# %%
newd_diff_key  =pd.merge(df_row,df4,left_on="id",right_on="customer_id")

# %%
newd_diff_key
# Out:
#   id Feature1 Feature2 customer_id  Feature3
# 0  1        A        B           1        12
# 1  1        K        L           1        12
# 2  2        C        D           2        13
# 3  2        M        N           2        13
# 4  3        E        F           3        14
# 5  4        G        H           4        15
# 6  5        I        J           5        16
# 7  7        Q        R           7        17
# 8  8        S        T           8        15

# %%
user_usage = pd.read_csv("https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/user_usage.csv")
user_usage
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
# [240 rows x 4 columns]

# %%
user_device = pd.read_csv('https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/user_device.csv')
user_device
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# ..      ...      ...      ...               ...                     ...
# 267   23049    29725  android               6.0                SM-G900F
# 268   23050    29726      ios              10.2               iPhone7,2
# 269   23051    29726      ios              10.2               iPhone7,2
# 270   23052    29727      ios              10.1               iPhone8,4
# 271   23053    20257  android               5.1  Vodafone Smart ultra 6
#
#      use_type_id
# 0              2
# 1              3
# 2              1
# 3              3
# ...

# %%
devices = pd.read_csv('https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/android_devices.csv')
devices
# Out:
#       Retail Branding Marketing Name       Device                      Model
# 0                 NaN            NaN       AD681H  Smartfren Andromax AD681H
# 1                 NaN            NaN        FJL21                      FJL21
# 2                 NaN            NaN          T31              Panasonic T31
# 3                 NaN            NaN     hws7721g         MediaPad 7 Youth 2
# 4                  3Q        OC1020A      OC1020A                    OC1020A
# ...               ...            ...          ...                        ...
# 14541           pendo    PNDPP44QC10  PNDPP44QC10                PNDPP44QC10
# 14542           pendo     PNDPP44QC7   PNDPP44QC7                 PNDPP44QC7
# 14543      sugar_aums         QPOINT        QPI-1                      QPI-1
# 14544       tecmobile       OmnisOne     OmnisOne                  Omnis One
# 14545           ucall          EASY1        EASY1                      EASY1
#
# [14546 rows x 4 columns]

# %%
data1 = pd.merge(user_usage,user_device[["use_id","platform","device"]],on="use_id",how="outer",indicator=True)
data1
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 348                      NaN                     NaN         NaN   23047
# 349                      NaN                     NaN         NaN   23048
# 350                      NaN                     NaN         NaN   23050
# 351                      NaN                     NaN         NaN   23051
# 352                      NaN                     NaN         NaN   23052
#
#     platform         device      _merge
# 0    android       GT-I9505        both
# ...

# %%
data1['_merge'].unique()
# Out:
# ['both', 'left_only', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
print(user_device.shape)
print(user_usage.shape)
# Out:
# (272, 6)
# (240, 4)

# %%
user_device.index
# Out:
# RangeIndex(start=0, stop=272, step=1)

# %%
data = pd.Series([1, 6, 7, [46, 56, 49], 45, [15, 10, 12]]).to_frame("dirty")

# %%
data
# Out:
#           dirty
# 0             1
# 1             6
# 2             7
# 3  [46, 56, 49]
# 4            45
# 5  [15, 10, 12]

# %%
data.explode('dirty',ignore_index=True)
# Out:
#   dirty
# 0     1
# 1     6
# 2     7
# 3    46
# 4    56
# 5    49
# 6    45
# 7    15
# 8    10
# 9    12

# %%
import numpy as np

# %%
df = pd.DataFrame({'A': [[0, 1, 2], 'foo', [], [3, 4]],'B': 1,'C': [['a', 'b', 'c'], np.nan, [], ['d', 'e']]})
df
# Out:
#            A  B          C
# 0  [0, 1, 2]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
df.explode('A')
# Out:
#      A  B          C
# 0    0  1  [a, b, c]
# 0    1  1  [a, b, c]
# 0    2  1  [a, b, c]
# 1  foo  1        NaN
# 2  NaN  1         []
# 3    3  1     [d, e]
# 3    4  1     [d, e]

# %%
df.explode(column=list("AC"))
# Out:
#      A  B    C
# 0    0  1    a
# 0    1  1    b
# 0    2  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %% [markdown]
# ## sqeeze

# %%
subset = data1.loc[data1.index <1,'outgoing_mins_per_month']
subset
# Out:
# 0    21.97
# Name: outgoing_mins_per_month, dtype: float64

# %%
type(subset)
# Out:
# pandas.core.series.Series

# %%
subset.squeeze()
# Out:
# 21.97

# %% [markdown]
# ## between

# %%
data1[data1['outgoing_mins_per_month'].between(30,50)]
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 8                      30.92                   22.77     3114.67   22799
# 53                     43.03                    0.47     2076.45   22882
# 54                     43.03                    0.47     2076.45   22883
# 55                     43.03                    0.47     2076.45   22884
# 71                     42.25                   37.06     1557.33   22909
# 116                    49.71                   38.02    15573.33   22982
# 131                    37.27                  136.10     1557.33   23005
# 139                    42.93                  124.33      519.12   23020
# 158                    42.75                   46.83     5191.12   23053
# 162                    46.40                   65.90     1557.33   23073
# 163                    38.56                   47.65     4025.86   23083
# 166                    41.60                   61.51     1557.33   23106
# ...

# %%
data1.describe().T.drop("count",axis=1).style.highlight_max(color="green")
# Out:
# <style type="text/css">
# #T_85094_row2_col1, #T_85094_row2_col6, #T_85094_row3_col0, #T_85094_row3_col2, #T_85094_row3_col3, #T_85094_row3_col4, #T_85094_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_85094">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85094_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_85094_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_85094_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_85094_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_85094_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_85094_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_85094_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data1.describe().T.drop("count",axis=1).style.highlight_min(color="green")
# Out:
# <style type="text/css">
# #T_bd769_row1_col0, #T_bd769_row1_col1, #T_bd769_row1_col3, #T_bd769_row1_col4, #T_bd769_row1_col5, #T_bd769_row1_col6, #T_bd769_row2_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_bd769">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd769_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_bd769_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_bd769_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_bd769_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_bd769_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_bd769_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_bd769_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data1.describe().T.drop("count",axis=1).style.background_gradient(subset=["mean","50%"],cmap="Oranges")
# Out:
# <style type="text/css">
# #T_3c5a4_row0_col0, #T_3c5a4_row0_col4 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_3c5a4_row1_col0, #T_3c5a4_row1_col4 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_3c5a4_row2_col0 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_3c5a4_row2_col4 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_3c5a4_row3_col0, #T_3c5a4_row3_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c5a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c5a4_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_3c5a4_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_3c5a4_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_3c5a4_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_3c5a4_level0_col4" class="col_heading level0 col4" >50%</th>
# ...

# %%
data1.dtypes
# Out:
# outgoing_mins_per_month     float64
# outgoing_sms_per_month      float64
# monthly_mb                  float64
# use_id                        int64
# platform                     object
# device                       object
# _merge                     category
# dtype: object

# %%
import numpy as np

# %%
data1.select_dtypes(exclude=np.number)
# Out:
#     platform         device      _merge
# 0    android       GT-I9505        both
# 1    android       SM-G930F        both
# 2    android       SM-G930F        both
# 3    android          D2303        both
# 4    android       SM-G361F        both
# ..       ...            ...         ...
# 348      ios      iPhone7,1  right_only
# 349  android  ONEPLUS A3003  right_only
# 350      ios      iPhone7,2  right_only
# 351      ios      iPhone7,2  right_only
# 352      ios      iPhone8,4  right_only
#
# [353 rows x 3 columns]

# %%
ages = pd.Series([55, 52, 50, 66, 57, 59, 49, 60]).to_frame("ages")
ages
# Out:
#    ages
# 0    55
# 1    52
# 2    50
# 3    66
# 4    57
# 5    59
# 6    49
# 7    60

# %%
ages.mask(cond=~ages['ages'].between(50,60),other="not in the list")
# Out:
#               ages
# 0               55
# 1               52
# 2               50
# 3  not in the list
# 4               57
# 5               59
# 6  not in the list
# 7               60

# %%
ages
# Out:
#    ages
# 0    55
# 1    52
# 2    50
# 3    66
# 4    57
# 5    59
# 6    49
# 7    60

# %%
ages['ages'].idxmax()
# Out:
# 3

# %%
ages['ages'].idxmin()
# Out:
# 6

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353 entries, 0 to 352
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outgoing_mins_per_month  240 non-null    float64
#  1   outgoing_sms_per_month   240 non-null    float64
#  2   monthly_mb               240 non-null    float64
#  3   use_id                   353 non-null    int64
#  4   platform                 272 non-null    object
#  5   device                   272 non-null    object
#  6   _merge                   353 non-null    category
# dtypes: category(1), float64(3), int64(1), object(2)
# memory usage: 19.8+ KB

# %%
data1[data1['outgoing_mins_per_month']>100]
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 10                    554.41                  150.06     3114.67   22804
# 11                    189.10                   24.08      519.12   22805
# 12                    283.30                  107.47    15573.33   22806
# ..                       ...                     ...         ...     ...
# 234                   558.52                   70.64     3334.28   24963
# 235                   260.66                   68.44      896.96   25008
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#     platform    device     _merge
# 1    android  SM-G930F       both
# ...

# %%
data1
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 348                      NaN                     NaN         NaN   23047
# 349                      NaN                     NaN         NaN   23048
# 350                      NaN                     NaN         NaN   23050
# 351                      NaN                     NaN         NaN   23051
# 352                      NaN                     NaN         NaN   23052
#
#     platform         device      _merge
# 0    android       GT-I9505        both
# ...

# %%
len(data1[data1['outgoing_mins_per_month']>100])
# Out:
# 166

# %%
data1['outgoing_mins_per_month'].value_counts(normalize=True)
# Out:
# 677.02    0.033333
# 583.73    0.020833
# 797.06    0.020833
# 71.59     0.016667
# 73.49     0.012500
#             ...
# 184.73    0.004167
# 305.58    0.004167
# 197.43    0.004167
# 361.19    0.004167
# 488.70    0.004167
# Name: outgoing_mins_per_month, Length: 178, dtype: float64
