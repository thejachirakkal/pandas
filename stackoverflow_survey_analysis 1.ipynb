# %%
import pandas as pd

# %%
course4 = {'Name':['ML','DL','CV'],
          'Duration':['6months','1year','3months'],
           'Domain':['Finance','Healthcare','Physics'],
           0.5:['list1','list2','list3']
          }

# %%
data = pd.DataFrame(course4)

# %%
data
# Out:
#   Name Duration      Domain    0.5
# 0   ML  6months     Finance  list1
# 1   DL    1year  Healthcare  list2
# 2   CV  3months     Physics  list3

# %% [markdown]
# ### iloc and loc

# %% [markdown]
# ## iloc(integer/index)

# %%
data
# Out:
#   Name Duration      Domain    0.5
# 0   ML  6months     Finance  list1
# 1   DL    1year  Healthcare  list2
# 2   CV  3months     Physics  list3

# %%
data.iloc[0]
# Out:
# Name             ML
# Duration    6months
# Domain      Finance
# 0.5           list1
# Name: 0, dtype: object

# %%
data.iloc[2]
# Out:
# Name             CV
# Duration    3months
# Domain      Physics
# 0.5           list3
# Name: 2, dtype: object

# %%
data.iloc[[0,2]]
# Out:
#   Name Duration   Domain    0.5
# 0   ML  6months  Finance  list1
# 2   CV  3months  Physics  list3

# %%
df1 =  pd.read_csv('titan.csv',index_col=[0])
df1
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
df = pd.read_csv('titan.csv',index_col=[0])
df
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
df.iloc[[0,-1]]
# Out:
#                         Name  Survived
# 0    Braund, Mr. Owen Harris         0
# 890      Dooley, Mr. Patrick         0

# %%
df.iloc[[0,890]]
# Out:
#                         Name  Survived
# 0    Braund, Mr. Owen Harris         0
# 890      Dooley, Mr. Patrick         0

# %%
df.iloc[[0,890,100,200],1]
# Out:
# 0      0
# 890    0
# 100    0
# 200    0
# Name: Survived, dtype: int64

# %%
df.iloc[0:50]
# Out:
#                                                  Name  Survived
# 0                             Braund, Mr. Owen Harris         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                              Heikkinen, Miss. Laina         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                            Allen, Mr. William Henry         0
# 5                                    Moran, Mr. James         0
# 6                             McCarthy, Mr. Timothy J         0
# 7                      Palsson, Master. Gosta Leonard         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)         1
# 10                    Sandstrom, Miss. Marguerite Rut         1
# 11                           Bonnell, Miss. Elizabeth         1
# 12                     Saundercock, Mr. William Henry         0
# 13                        Andersson, Mr. Anders Johan         0
# ...

# %%
df.iloc[0:50,1]
# Out:
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    0
# 13    0
# 14    0
# 15    1
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    1
# 23    1
# 24    0
# 25    1
# 26    0
# 27    0
# 28    1
# 29    0
# 30    0
# 31    1
# 32    1
# 33    0
# 34    0
# 35    0
# 36    1
# 37    0
# 38    0
# 39    1
# 40    0
# 41    0
# 42    0
# 43    1
# 44    1
# 45    0
# 46    0
# 47    1
# 48    0
# 49    0
# Name: Survived, dtype: int64

# %%
stock = pd.read_csv('stock_px.csv',index_col=[0])
stock
# Out:
#                         AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                    ...     ...    ...     ...    ...    ...    ...
# 2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#                          SPX    XOM
# 1990-02-01 00:00:00   328.79   6.12
# 1990-02-02 00:00:00   330.92   6.24
# ...

# %%
stock.iloc[0,5]
# Out:
# 0.51

# %% [markdown]
# ## loc

# %%
df
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
df.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[[100,200,300],'Name']
# Out:
# 100                     Petranec, Miss. Matilda
# 200              Vande Walle, Mr. Nestor Cyriel
# 300    Kelly, Miss. Anna Katherine "Annie Kate"
# Name: Name, dtype: object

# %%
df.loc[0]
# Out:
# Name        Braund, Mr. Owen Harris
# Survived                          0
# Name: 0, dtype: object

# %%
df2 = pd.DataFrame(course4,index=['one','two','three'])

# %%
df2
# Out:
#       Name Duration      Domain    0.5
# one     ML  6months     Finance  list1
# two     DL    1year  Healthcare  list2
# three   CV  3months     Physics  list3

# %%
df2.iloc[1,2]
# Out:
# 'Healthcare'

# %%
df2.loc['two']
# Out:
# Name                DL
# Duration         1year
# Domain      Healthcare
# 0.5              list2
# Name: two, dtype: object

# %%
df2.loc['two','Domain']
# Out:
# 'Healthcare'

# %% [markdown]
# - iloc access data by integer location
# - we are using labels to get data(here index for rows and column name for columns)

# %%
stock
# Out:
#                         AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                    ...     ...    ...     ...    ...    ...    ...
# 2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#                          SPX    XOM
# 1990-02-01 00:00:00   328.79   6.12
# 1990-02-02 00:00:00   330.92   6.24
# ...

# %%
df.loc[[0,100,200],'Name']
# Out:
# 0             Braund, Mr. Owen Harris
# 100           Petranec, Miss. Matilda
# 200    Vande Walle, Mr. Nestor Cyriel
# Name: Name, dtype: object

# %%
df.loc[100:150]
# Out:
#                                                   Name  Survived
# 100                            Petranec, Miss. Matilda         0
# 101                   Petroff, Mr. Pastcho ("Pentcho")         0
# 102                          White, Mr. Richard Frasar         0
# 103                         Johansson, Mr. Gustaf Joel         0
# 104                     Gustafsson, Mr. Anders Vilhelm         0
# 105                              Mionoff, Mr. Stoytcho         0
# 106                   Salkjelsvik, Miss. Anna Kristine         1
# 107                             Moss, Mr. Albert Johan         1
# 108                                    Rekic, Mr. Tido         0
# 109                                Moran, Miss. Bertha         1
# 110                     Porter, Mr. Walter Chamberlain         0
# 111                               Zabour, Miss. Hileni         0
# 112                             Barton, Mr. David John         0
# ...

# %%
stock.index
# Out:
# Index(['1990-02-01 00:00:00', '1990-02-02 00:00:00', '1990-02-05 00:00:00',
#        '1990-02-06 00:00:00', '1990-02-07 00:00:00', '1990-02-08 00:00:00',
#        '1990-02-09 00:00:00', '1990-02-12 00:00:00', '1990-02-13 00:00:00',
#        '1990-02-14 00:00:00',
#        ...
#        '2011-10-03 00:00:00', '2011-10-04 00:00:00', '2011-10-05 00:00:00',
#        '2011-10-06 00:00:00', '2011-10-07 00:00:00', '2011-10-10 00:00:00',
#        '2011-10-11 00:00:00', '2011-10-12 00:00:00', '2011-10-13 00:00:00',
#        '2011-10-14 00:00:00'],
#       dtype='object', length=5472)

# %%
df.loc[5:10]
# Out:
#                                                  Name  Survived
# 5                                    Moran, Mr. James         0
# 6                             McCarthy, Mr. Timothy J         0
# 7                      Palsson, Master. Gosta Leonard         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)         1
# 10                    Sandstrom, Miss. Marguerite Rut         1

# %%
stock.loc['1990-02-01 00:00:00':'1990-02-14 00:00:00','AAPL':'PEP']
# Out:
#                      AAPL    GE    IBM   JNJ  MSFT   PEP
# 1990-02-01 00:00:00  7.86  2.87  16.79  4.27  0.51  6.04
# 1990-02-02 00:00:00  8.00  2.87  16.89  4.37  0.51  6.09
# 1990-02-05 00:00:00  8.18  2.87  17.32  4.34  0.51  6.05
# 1990-02-06 00:00:00  8.12  2.88  17.56  4.32  0.51  6.15
# 1990-02-07 00:00:00  7.77  2.91  17.93  4.38  0.51  6.17
# 1990-02-08 00:00:00  7.71  2.92  17.86  4.46  0.51  6.22
# 1990-02-09 00:00:00  8.00  2.94  17.82  4.49  0.52  6.24
# 1990-02-12 00:00:00  7.94  2.89  17.58  4.46  0.52  6.23
# 1990-02-13 00:00:00  8.06  2.88  17.95  4.43  0.52  6.09
# 1990-02-14 00:00:00  8.00  2.89  18.04  4.47  0.52  6.10

# %%
df.loc[845:]
# Out:
#                                                   Name  Survived
# 845                                Abbing, Mr. Anthony         0
# 846                           Sage, Mr. Douglas Bullen         0
# 847                                 Markoff, Mr. Marin         0
# 848                                  Harper, Rev. John         0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)         1
# 850            Andersson, Master. Sigvard Harald Elias         0
# 851                                Svensson, Mr. Johan         0
# 852                            Boulos, Miss. Nourelain         0
# 853                          Lines, Miss. Mary Conover         1
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)         0
# 855                         Aks, Mrs. Sam (Leah Rosen)         1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)         1
# 857                             Daly, Mr. Peter Denis          1
# ...

# %%
df.loc[845:,"Name":]
# Out:
#                                                   Name  Survived
# 845                                Abbing, Mr. Anthony         0
# 846                           Sage, Mr. Douglas Bullen         0
# 847                                 Markoff, Mr. Marin         0
# 848                                  Harper, Rev. John         0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)         1
# 850            Andersson, Master. Sigvard Harald Elias         0
# 851                                Svensson, Mr. Johan         0
# 852                            Boulos, Miss. Nourelain         0
# 853                          Lines, Miss. Mary Conover         1
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)         0
# 855                         Aks, Mrs. Sam (Leah Rosen)         1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)         1
# 857                             Daly, Mr. Peter Denis          1
# ...

# %%
df.loc[845:,:"Survived"]
# Out:
#                                                   Name  Survived
# 845                                Abbing, Mr. Anthony         0
# 846                           Sage, Mr. Douglas Bullen         0
# 847                                 Markoff, Mr. Marin         0
# 848                                  Harper, Rev. John         0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)         1
# 850            Andersson, Master. Sigvard Harald Elias         0
# 851                                Svensson, Mr. Johan         0
# 852                            Boulos, Miss. Nourelain         0
# 853                          Lines, Miss. Mary Conover         1
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)         0
# 855                         Aks, Mrs. Sam (Leah Rosen)         1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)         1
# 857                             Daly, Mr. Peter Denis          1
# ...

# %% [markdown]
#     Create a dictionary which contains keys> Name, Marks,Result
#     convert dictionary into dataframe
#     Access values using square barackets
#     access values using iloc
#     access values using loc

# %%
import numpy as np

# %%
data = pd.DataFrame({
    "val":[1,2,3],
    "res":['Pass','Fail','Pass','Pass']
})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data = pd.DataFrame({
#       2     "val":[1,2,3],
#       3     "res":['Pass','Fail','Pass','Pass']
#       4 })
#       5 data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Duration  3 non-null      object
#  2   Domain    3 non-null      object
#  3   0.5       3 non-null      object
# dtypes: object(4)
# memory usage: 228.0+ bytes

# %%
# !dir
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is BE03-3FCA
#
#  Directory of D:\CodeMe\implementation
#
# 07/26/2023  04:32 PM    <DIR>          .
# 07/26/2023  04:32 PM    <DIR>          ..
# 07/24/2023  11:36 AM    <DIR>          .idea
# 07/25/2023  09:15 AM           237,273 .ipynb
# 07/25/2023  09:34 AM    <DIR>          .ipynb_checkpoints
# 02/18/2019  10:37 AM               111 csv_mindex.csv
# 12/04/2021  03:33 PM                59 demo1.csv
# 12/04/2021  07:05 PM            10,545 demo1.xlsx
# 12/04/2021  03:36 PM                43 demo2.csv
# 02/18/2019  10:37 AM               169 demo3.csv
# 02/18/2019  10:37 AM               170 demo3.txt
# 12/04/2021  04:35 PM               169 demo4.csv
# 02/18/2019  10:37 AM                78 demo5.csv
# 02/18/2019  10:37 AM           626,863 demo6.csv
# 02/18/2019  10:37 AM                36 demo7.csv
# 12/04/2021  04:49 PM             6,189 demo_file.xlsx
# 02/18/2019  10:37 AM           281,823 fdic_failed_bank_list.html
# ...

# %% [markdown]
# ## Stackoverflow Data Analysis

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
df.select_dtypes(['int64',"float64"])
# Out:
#        Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0               1        NaN            NaN          NaN         NaN  14.0
# 1               2        NaN            NaN          NaN         NaN  19.0
# 2               3    23000.0         8820.0         40.0         NaN  28.0
# 3               4    61000.0        61000.0         80.0         NaN  22.0
# 4               5        NaN            NaN         55.0         NaN  30.0
# ...           ...        ...            ...          ...         ...   ...
# 88878       88377        NaN            NaN          NaN         NaN   NaN
# 88879       88601        NaN            NaN          NaN         NaN   NaN
# 88880       88802        NaN            NaN          NaN         NaN   NaN
# 88881       88816        NaN            NaN          NaN         NaN   NaN
# 88882       88863        NaN            NaN          NaN         NaN  18.0
#
# [88883 rows x 6 columns]

# %%
df['CompTotal']
# Out:
# 0            NaN
# 1            NaN
# 2        23000.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: CompTotal, Length: 88883, dtype: float64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
pd.set_option("display.max_columns",85)#will display maximum numer of columns

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(20)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
pd.set_option("display.max_rows",200)#to show minimum these many rows

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.set_option("display.max_rows",200)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema =pd.read_csv('survey_results_schema.csv')
schema
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
schema.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
schema.loc[2,"QuestionText"]
# Out:
# 'Do you code as a hobby?'

# %%
df['Hobbyist'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Hobbyist'].value_counts()#return the number of ocurences(how frequent) of each value inside a feature
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %% [markdown]
# ## loc and iloc

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[99,'EdLevel']
# Out:
# 'Some college/university study without earning a degree'

# %%
df.loc[999,["Country","EdLevel","Hobbyist"]]
# Out:
# Country                                           Philippines
# EdLevel     Secondary school (e.g. American high school, G...
# Hobbyist                                                  Yes
# Name: 999, dtype: object

# %%
df.loc[999,'Country':'YearsCodePro']
# Out:
# Country                                                 Philippines
# Student                                              Yes, full-time
# EdLevel           Secondary school (e.g. American high school, G...
# UndergradMajor                                                  NaN
# EduOther          Taken an online course in programming or softw...
# OrgSize                                                         NaN
# DevType           Designer;Developer, back-end;Developer, deskto...
# YearsCode                                                         3
# Age1stCode                                                       16
# YearsCodePro                                                    NaN
# Name: 999, dtype: object

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.loc[[9,99,999,9999],["EdLevel",'Hobbyist']]
# Out:
#                                                 EdLevel Hobbyist
# 9           Master’s degree (MA, MS, M.Eng., MBA, etc.)      Yes
# 99    Some college/university study without earning ...      Yes
# 999   Secondary school (e.g. American high school, G...      Yes
# 9999           Bachelor’s degree (BA, BS, B.Eng., etc.)      Yes

# %%
df.loc[99:199,'EdLevel']
# Out:
# 99     Some college/university study without earning ...
# 100             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 102                                     Associate degree
# 103             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 104             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 105          Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 106          Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 107             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 108          Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 109          Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 110             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 111    Secondary school (e.g. American high school, G...
# 112             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 113             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 114                                     Associate degree
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[:20,"Country"]
# Out:
# 0             United Kingdom
# 1     Bosnia and Herzegovina
# 2                   Thailand
# 3              United States
# 4                    Ukraine
# 5                     Canada
# 6                    Ukraine
# 7                      India
# 8                New Zealand
# 9                      India
# 10       Antigua and Barbuda
# 11                    Canada
# 12             United States
# 13                   Germany
# 14                     India
# 15            United Kingdom
# 16                 Australia
# 17        Russian Federation
# 18                    Brazil
# 19                 Lithuania
# 20                    Canada
# Name: Country, dtype: object

# %%
#do the same with iloc

# %%
df.loc[88863:,"CompTotal"]
# Out:
# 88863   NaN
# 88864   NaN
# 88865   NaN
# 88866   NaN
# 88867   NaN
# 88868   NaN
# 88869   NaN
# 88870   NaN
# 88871   NaN
# 88872   NaN
# 88873   NaN
# 88874   NaN
# 88875   NaN
# 88876   NaN
# 88877   NaN
# 88878   NaN
# 88879   NaN
# 88880   NaN
# 88881   NaN
# 88882   NaN
# Name: CompTotal, dtype: float64

# %%
88883-20
# Out:
# 88863

# %%
df.loc[1000:1020,['Country','Age','Gender']]
# Out:
#              Country   Age                                             Gender
# 1000  United Kingdom  38.0                                                Man
# 1001  United Kingdom  25.0  Non-binary, genderqueer, or gender non-conforming
# 1002           India  25.0                                                Man
# 1003          Mexico  27.0                                                Man
# 1004         Finland  38.0                                                Man
# 1005   United States  26.0                                              Woman
# 1006            Iran  27.0                                                Man
# 1007           India   NaN                                                Man
# 1008          Greece   NaN                                                NaN
# 1009          Turkey  26.0                                                Man
# 1010        Slovenia   NaN                                                Man
# ...

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Man                                                            0.912336
# Woman                                                          0.074280
# Non-binary, genderqueer, or gender non-conforming              0.006990
# Man;Non-binary, genderqueer, or gender non-conforming          0.002119
# Woman;Non-binary, genderqueer, or gender non-conforming        0.001909
# Woman;Man                                                      0.001546
# Woman;Man;Non-binary, genderqueer, or gender non-conforming    0.000820
# Name: Gender, dtype: float64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[100:150,'CompTotal':'PurchaseWhat']
# Out:
#      CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 100        NaN  Monthly            NaN         40.0
# 101    67800.0   Weekly      2000000.0         40.0
# 102        NaN      NaN            NaN          NaN
# 103   155000.0   Yearly         2169.0          6.0
# 104    45000.0   Yearly        45000.0         40.0
# 105   160000.0   Yearly       160000.0         35.0
# 106        NaN      NaN            NaN          NaN
# 107   140000.0   Yearly       140000.0         40.0
# 108    25000.0  Monthly        46368.0         40.0
# 109   100000.0   Yearly       100000.0         45.0
# 110        NaN      NaN            NaN          NaN
# 111        NaN      NaN            NaN         12.0
# 112   300000.0  Monthly        54996.0         45.0
# 113    70000.0   Yearly        53437.0         45.0
# 114    30000.0  Monthly        39768.0         40.0
# 115    90000.0   Yearly       103117.0         45.0
# 116    26000.0   Yearly        26000.0         45.0
# ...

# %%
schema
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema.loc[37]
# Out:
# Column                                                     ImpSyn
# QuestionText    For the specific work you do, and the years of...
# Name: 37, dtype: object

# %% [markdown]
# ## index

# %%
df3 = pd.read_csv("survey_results_public.csv",index_col="Respondent")

# %%
df3.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
#try set_index method

# %%
df3.loc[1000]
# Out:
# MainBranch                                   I am a developer by profession
# Hobbyist                                                                Yes
# OpenSourcer               Less than once a month but more than once per ...
# OpenSource                OSS is, on average, of HIGHER quality than pro...
# Employment                                               Employed part-time
# Country                                                         Netherlands
# Student                                                                  No
# EdLevel                            Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor                                                          NaN
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                       2-9 employees
# DevType                   Developer, front-end;Developer, full-stack;Dev...
# ...

# %%
df3.dtypes
# Out:
# MainBranch                 object
# Hobbyist                   object
# OpenSourcer                object
# OpenSource                 object
# Employment                 object
# Country                    object
# Student                    object
# EdLevel                    object
# UndergradMajor             object
# EduOther                   object
# OrgSize                    object
# DevType                    object
# YearsCode                  object
# Age1stCode                 object
# YearsCodePro               object
# CareerSat                  object
# JobSat                     object
# MgrIdiot                   object
# MgrMoney                   object
# MgrWant                    object
# JobSeek                    object
# LastHireDate               object
# LastInt                    object
# FizzBuzz                   object
# JobFactors                 object
# ResumeUpdate               object
# CurrencySymbol             object
# ...

# %%
df.select_dtypes(include="float64").columns
# Out:
# Index(['CompTotal', 'ConvertedComp', 'WorkWeekHrs', 'CodeRevHrs', 'Age'], dtype='object')

# %%
df3.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema2 = pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema2
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema2.loc["Age"]
# Out:
# QuestionText    What is your age (in years)? If you prefer not...
# Name: Age, dtype: object

# %%
df3.loc[2,"EdLevel"]
# Out:
# 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'

# %%
schema2.loc['YearsCodePro',"QuestionText"]
# Out:
# 'How many years have you coded professionally (as a part of your work)?'

# %%
schema2.loc["DevEnviron","QuestionText"]
# Out:
# 'Which development environment(s) do you use regularly?  Please check all that apply.'

# %%
schema2
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema2.sort_index(ascending=False)#to sort the index
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
schema2.loc['ImpSyn']
# Out:
# QuestionText    For the specific work you do, and the years of...
# Name: ImpSyn, dtype: object

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema2.sort_index(inplace=True)

# %%
schema2
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# - Create a data frame which inlcudes a columns with serial number and id columns
# - make serial column as an index
# - make id column into index
# - access value using both indices(serial,id)
#
# - On survery Data
#     - How old all the fist 30 respondents
#     - Preferred gender of 50 to 100 respondents
#     - Most number of repondents are from which country
#     - EdLevel and YearsCodPro of 1000 to 1050
#     - How many respondents are students
#     - Reponse of first 20 respondents to  "Student"  to "YearsCodePro"
#     - Return  the columns names of all the object type columns
#     - Return Feature with most number of Nan values

# %% [markdown]
# ### Data Filtering

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
schema2
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df3.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df3.loc[:,"ConvertedComp"]
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
schema2.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
schema2.loc["ConvertedComp","QuestionText"]
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
df3["ConvertedComp"].dtype
# Out:
# dtype('float64')

# %%
df3["ConvertedComp"].max()
# Out:
# 2000000.0

# %%
df3["ConvertedComp"].min()
# Out:
# 0.0

# %% [markdown]
# #### Respondents those earns more than 90000

# %%
df3["ConvertedComp"] > 90000
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: ConvertedComp, Length: 88883, dtype: bool

# %%
df3[df3["ConvertedComp"] > 90000]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88874                          I am a developer by profession      Yes
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 6                                Never
# ...

# %%
df3[df3['ConvertedComp'] > 500000]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 32                             I am a developer by profession       No
# 58                             I am a developer by profession      Yes
# 102                            I am a developer by profession       No
# 128         I am not primarily a developer, but I write co...      Yes
# 155                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88818                          I am a developer by profession      Yes
# 88868                          I am a developer by profession      Yes
# 88874                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 32                               Never
# ...

# %%
df3[df3['ConvertedComp'] < 5000]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 59                             I am a developer by profession      Yes
# 71                             I am a developer by profession      Yes
# 84                             I am a developer by profession       No
# 104                            I am a developer by profession      Yes
# 169                            I am a developer by profession       No
# ...                                                       ...      ...
# 88661       I am not primarily a developer, but I write co...      Yes
# 88676                          I am a developer by profession      Yes
# 88715                          I am a developer by profession      Yes
# 88722                          I am a developer by profession       No
# 88852                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
highest_earners = df3['ConvertedComp'] > 1000000

# %%
highest_earners
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: ConvertedComp, Length: 88883, dtype: bool

# %%
df3[highest_earners]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 32          I am a developer by profession       No
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 274         I am a developer by profession       No
# ...                                    ...      ...
# 88712       I am a developer by profession      Yes
# 88815       I am a developer by profession      Yes
# 88818       I am a developer by profession      Yes
# 88874       I am a developer by profession      Yes
# 88877       I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 32                               Never
# 58          Once a month or more often
# 102                              Never
# 166            Less than once per year
# 274                              Never
# ...                                ...
# ...

# %%
len(df3[highest_earners])
# Out:
# 1118

# %%
df3[highest_earners].shape
# Out:
# (1118, 84)

# %% [markdown]
# ##### Takeaway:
#     - 1118 respondents are earns more than 1000000

# %%
top_bottom = (df3['ConvertedComp'] > 50000) & (df3['ConvertedComp'] < 100000)

# %%
df3[top_bottom].shape
# Out:
# (16538, 84)

# %%
df3[top_bottom]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 14                             I am a developer by profession      Yes
# 17                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88860                          I am a developer by profession       No
# 88861       I am not primarily a developer, but I write co...       No
# 88873                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# Takeaway:
#     - Developers who earns between 50000 and 100000 is 16538

# %%
dev_details=df3.loc[top_bottom,["Country","EdLevel","UndergradMajor","Age"]]

# %%
dev_details
# Out:
#                   Country                                            EdLevel  \
# Respondent
# 4           United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9             New Zealand  Some college/university study without earning ...
# 13          United States        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 14                Germany          Other doctoral degree (Ph.D, Ed.D., etc.)
# 17              Australia           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                   ...                                                ...
# 88860        South Africa           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88861             Germany  Secondary school (e.g. American high school, G...
# 88873              Canada  Some college/university study without earning ...
# 88879             Finland        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88881             Austria        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#if i want to get certain features of developers who earns less than 5000

# %%
dev_less=df3.loc[(df3['ConvertedComp']>100) & (df3['ConvertedComp'] < 5000),"MainBranch":"JobSat"]

# %%
dev_less
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 59                             I am a developer by profession      Yes
# 71                             I am a developer by profession      Yes
# 84                             I am a developer by profession       No
# 104                            I am a developer by profession      Yes
# 169                            I am a developer by profession       No
# ...                                                       ...      ...
# 88661       I am not primarily a developer, but I write co...      Yes
# 88676                          I am a developer by profession      Yes
# 88715                          I am a developer by profession      Yes
# 88722                          I am a developer by profession       No
# 88852                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3[df3['ConvertedComp'] < 5000]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 59                             I am a developer by profession      Yes
# 71                             I am a developer by profession      Yes
# 84                             I am a developer by profession       No
# 104                            I am a developer by profession      Yes
# 169                            I am a developer by profession       No
# ...                                                       ...      ...
# 88661       I am not primarily a developer, but I write co...      Yes
# 88676                          I am a developer by profession      Yes
# 88715                          I am a developer by profession      Yes
# 88722                          I am a developer by profession       No
# 88852                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# > Developers whose Converted Comp greater than 3L and less than 15L, and i want to know which gender are they and their Country

# %% [markdown]
# - Greater than 3 L
# - Less than 15 L
# - Gender and their country

# %%
df.dtypes
# Out:
# Respondent                  int64
# MainBranch                 object
# Hobbyist                   object
# OpenSourcer                object
# OpenSource                 object
# Employment                 object
# Country                    object
# Student                    object
# EdLevel                    object
# UndergradMajor             object
# EduOther                   object
# OrgSize                    object
# DevType                    object
# YearsCode                  object
# Age1stCode                 object
# YearsCodePro               object
# CareerSat                  object
# JobSat                     object
# MgrIdiot                   object
# MgrMoney                   object
# MgrWant                    object
# JobSeek                    object
# LastHireDate               object
# LastInt                    object
# FizzBuzz                   object
# JobFactors                 object
# ResumeUpdate               object
# ...

# %%
df3['Age'].min()
# Out:
# 1.0

# %%
df3['Age'].max()
# Out:
# 99.0

# %%
#more than 10L or age 50

# %%
df3.loc[(df3['ConvertedComp'] > 1000000) | ( df3['Age'] == 50),['ConvertedComp',"Age"]]
# Out:
#             ConvertedComp   Age
# Respondent
# 32              1100000.0  21.0
# 58              2000000.0  47.0
# 102             2000000.0  37.0
# 166             2000000.0  30.0
# 274             1380000.0  35.0
# ...                   ...   ...
# 88877           2000000.0  48.0
# 26927                 NaN  50.0
# 34138                 NaN  50.0
# 39382                 NaN  50.0
# 61753                 NaN  50.0
#
# [1576 rows x 2 columns]

# %%
#20-30, conv,Country

# %%
young=df3.loc[df3['Age'].between(20,30),['ConvertedComp','Country','Age']]

# %%
young['Age'].max()
# Out:
# 30.0

# %%
#age 2-30
# salary-15L
# Gender -Female

# %%
df3.Gender.unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man',
#        'Man;Non-binary, genderqueer, or gender non-conforming'],
#       dtype=object)

# %%
df3.Gender.value_counts()
# Out:
# Man                                                            77919
# Woman                                                           6344
# Non-binary, genderqueer, or gender non-conforming                597
# Man;Non-binary, genderqueer, or gender non-conforming            181
# Woman;Non-binary, genderqueer, or gender non-conforming          163
# Woman;Man                                                        132
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       70
# Name: Gender, dtype: int64

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
women_top=df3.loc[df3['Gender']=="Woman",['Country',"YearsCodePro","ConvertedComp","Gender"]]

# %%
women_top
# Out:
#                    Country      YearsCodePro  ConvertedComp Gender
# Respondent
# 12                  Canada               NaN            NaN  Woman
# 31                  Canada               NaN            NaN  Woman
# 35           United States                14        80000.0  Woman
# 51           United States               NaN            NaN  Woman
# 71             Philippines  Less than 1 year         4128.0  Woman
# ...                    ...               ...            ...    ...
# 82007               Canada                 1            NaN  Woman
# 83397        United States  Less than 1 year            NaN  Woman
# 83612             Thailand  Less than 1 year            NaN  Woman
# 84539       United Kingdom                 6            NaN  Woman
# 85182               Canada               NaN            NaN  Woman
#
# [6344 rows x 4 columns]

# %%
df3['Hobbyist']=="Yes"
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df3.loc[df3['Country'].isin(["Ukraine",'India']),:]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 5                   I am a developer by profession      Yes
# 7                   I am a developer by profession       No
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 5                                  Once a month or more often
# 7                                                       Never
# ...

# %%
does_india_exist = df3['Country'].isin(['India'])
df3[does_india_exist]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# - 1
#
# #age 2-30
# # salary-15L
# # Gender -Female
#
# - 2
#
# Developers who gets more than 15L, and are they satisfied in their working environment
#
#
# - 3
#
# Does SAARC countries exist in the dataframe
#
# - 4
#
# Female Developers those earns more than 10L and thier age when they first code
#
# - 5
#
# Working Location and Edulevel of developers who gets 20L
