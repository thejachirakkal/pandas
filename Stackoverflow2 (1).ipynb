# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.read_csv('survey_results_public.csv',index_col=['Respondent'])
df3.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema2 = pd.read_csv('survey_results_schema.csv',index_col=['Column'])

# %%
schema2.sort_index(inplace=True)

# %%
schema2
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4 = df3.copy()

# %%
#curse of dimensionality

# %%
df3['ITperson']
# Out:
# Respondent
# 1        Fortunately, someone else has that title
# 2                                             Yes
# 3                                             Yes
# 4                                            SIGH
# 5                                        Also Yes
#                            ...
# 88377                                         Yes
# 88601                                         NaN
# 88802                                         NaN
# 88816                                         NaN
# 88863                                    Also Yes
# Name: ITperson, Length: 88883, dtype: object

# %%
schema2.loc['MiscTechDesireNextYear',"QuestionText"]
# Out:
# 'Which of the following other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)'

# %%
# df3.drop(['MiscTechDesireNextYear'],axis=1,inplace=True)

# %%
feat_to_remove = ['LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith']

# %%
df3.drop(feat_to_remove,axis=1,inplace=True)

# %%
df3.loc[1000]
# Out:
# MainBranch                         I am a developer by profession
# Hobbyist                                                      Yes
# OpenSourcer     Less than once a month but more than once per ...
# OpenSource      OSS is, on average, of HIGHER quality than pro...
# Employment                                     Employed part-time
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                            White or of European descent
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                                                   Easy
# Name: 1000, Length: 81, dtype: object

# %%
df3.columns

# %%
rows_to_remove=df3.loc[340:350]
rows_to_remove
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 340                            I am a developer by profession      Yes
# 341                            I am a developer by profession      Yes
# 342                            I am a developer by profession      Yes
# 343                            I am a developer by profession      Yes
# 344                            I am a developer by profession      Yes
# 345                            I am a developer by profession      Yes
# 346                    I am a student who is learning to code      Yes
# 347                            I am a developer by profession      Yes
# 348                            I am a developer by profession      Yes
# 349         I am not primarily a developer, but I write co...       No
# 350                            I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df4
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df4.drop(rows_to_remove,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df4.drop(rows_to_remove,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
rows_to_remove = df3.loc[4:10,:]
rows_to_remove
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 4                                Never
# 5           Once a month or more often
# 6                                Never
# 7                                Never
# 8              Less than once per year
# 9           Once a month or more often
# 10          Once a month or more often
#
# ...

# %%
rows_to_remove.index
# Out:
# Int64Index([4, 5, 6, 7, 8, 9, 10], dtype='int64', name='Respondent')

# %%
df3.drop(rows_to_remove,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df3.drop(rows_to_remove,axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df3
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3.loc[20:30,:]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 20          I am not primarily a developer, but I write co...       No
# 21                                I code primarily as a hobby      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 24                             I am a developer by profession      Yes
# 25                             I am a developer by profession       No
# 26                             I am a developer by profession      Yes
# 27          I used to be a developer by profession, but no...      Yes
# 28                             I am a developer by profession      Yes
# 29                             I am a developer by profession      Yes
# 30                             I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
rows_to_remove
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 4                                Never
# 5           Once a month or more often
# 6                                Never
# 7                                Never
# 8              Less than once per year
# 9           Once a month or more often
# 10          Once a month or more often
#
# ...

# %%
df3.drop(rows_to_remove.index,axis=0,inplace=True)

# %%
df3
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3.drop([14,15,16],axis=0).head(20)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# 13                             I am a developer by profession      Yes
# 17                             I am a developer by profession      Yes
# 18          I am not primarily a developer, but I write co...      Yes
# 19                             I am a developer by profession      Yes
# 20          I am not primarily a developer, but I write co...       No
# 21                                I code primarily as a hobby      Yes
# 22                             I am a developer by profession      Yes
# ...

# %%
col_to_remov = ['MainBranch','Hobbyist','OpenSourcer']

# %%
col_to_remov2 = df3.loc[:,"Country":"UndergradMajor"]
col_to_remov2
# Out:
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 11             Antigua and Barbuda  Yes, full-time
# 12                          Canada  Yes, full-time
# ...                            ...             ...
# 88377                       Canada              No
# 88601                          NaN             NaN
# 88802                          NaN             NaN
# 88816                          NaN             NaN
# 88863                        Spain  Yes, full-time
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11                                  Primary/elementary school
# ...

# %%
df3.drop(col_to_remov2,axis=1)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
col_to_remov2
# Out:
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 11             Antigua and Barbuda  Yes, full-time
# 12                          Canada  Yes, full-time
# ...                            ...             ...
# 88377                       Canada              No
# 88601                          NaN             NaN
# 88802                          NaN             NaN
# 88816                          NaN             NaN
# 88863                        Spain  Yes, full-time
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11                                  Primary/elementary school
# ...

# %%
rows_to_remv = df3.loc[30:35,:]
rows_to_remv
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 30                  I am a developer by profession       No
# 31          I am a student who is learning to code       No
# 32                  I am a developer by profession       No
# 33                  I am a developer by profession       No
# 34          I am a student who is learning to code      Yes
# 35                  I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 30          Less than once a month but more than once per ...
# 31                                                      Never
# 32                                                      Never
# 33          Less than once a month but more than once per ...
# 34                                                      Never
# 35                                                      Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
df3.loc[60:70]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 60                             I am a developer by profession      Yes
# 61                             I am a developer by profession      Yes
# 62                             I am a developer by profession      Yes
# 63                             I am a developer by profession      Yes
# 64          I am not primarily a developer, but I write co...      Yes
# 65                             I am a developer by profession      Yes
# 66                             I am a developer by profession      Yes
# 67          I am not primarily a developer, but I write co...       No
# 68                             I am a developer by profession      Yes
# 69                             I am a developer by profession      Yes
# 70                             I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3.drop(df3.loc[60:70,:].index,axis=0)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3 = df3.drop("EduOther",axis=1)

# %%
df3
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema3 = schema2.sort_index(ascending=False)

# %%
schema3
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
schema2.loc['LanguageWorkedWith','QuestionText']
# Out:
# 'Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
df3['LanguageWorkedWith'].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3.shape
# Out:
# (88876, 80)

# %% [markdown]
# ### how to get developers who mainly use python as their primary programming language

# %%
df3["LanguageWorkedWith"].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3["LanguageWorkedWith"].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3["LanguageWorkedWith"].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# df3.isna()

# %%
df3[df3['ConvertedComp'].isnull()]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 11                     I code primarily as a hobby      Yes
# 12          I am a student who is learning to code       No
# 15          I am a student who is learning to code      Yes
# ...                                            ...      ...
# 88377                                          NaN      Yes
# 88601                                          NaN       No
# 88802                                          NaN       No
# 88816                                          NaN       No
# 88863                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df3.loc[df3["LanguageWorkedWith"].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3["LanguageWorkedWith"].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
filt1=df3['LanguageWorkedWith'].str.contains("Python",na=False)#ignore nan values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df3['LanguageWorkedWith'].tail(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
filt1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 filt1
#
# NameError: name 'filt1' is not defined

# %%
pd.options.display.max_colwidth = 100

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
py_users = df3.loc[filt1,["LanguageWorkedWith","Age1stCode"]]
py_users
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 py_users = df3.loc[filt1,["LanguageWorkedWith","Age1stCode"]]
#       2 py_users
#
# NameError: name 'filt1' is not defined

# %% [markdown]
# Takeaway: 36438 developers are using python as their primary programming language

# %%
py_users.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 py_users.dtypes
#
# NameError: name 'py_users' is not defined

# %%
py_users['Age1stCode'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 py_users['Age1stCode'].unique()
#
# NameError: name 'py_users' is not defined

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
schema2.loc["WebFrameWorkedWith"]
# Out:
# QuestionText    Which of the following web frameworks have you done extensive development work in over the past ...
# Name: WebFrameWorkedWith, dtype: object

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
df3['DatabaseDesireNextYear'].unique()
# Out:
# array(['MySQL', 'PostgreSQL', nan, ...,
#        'Cassandra;Couchbase;MariaDB;Microsoft SQL Server;MySQL',
#        'Couchbase;Firebase;Microsoft SQL Server;Oracle;SQLite',
#        'DynamoDB;MariaDB;MongoDB;Microsoft SQL Server;MySQL;PostgreSQL;SQLite;Other(s):'],
#       dtype=object)

# %%
df3["JobSat"].unique()
# Out:
# array([nan, 'Slightly satisfied', 'Very satisfied',
#        'Neither satisfied nor dissatisfied', 'Slightly dissatisfied',
#        'Very dissatisfied'], dtype=object)

# %%
# df3['WebFrameWorkedWith'].str.contains('Flask')

# %%
df3['LastHireDate'].unique()
# Out:
# array([nan, "I've never had a job", '1-2 years ago',
#        'Less than a year ago', '3-4 years ago', 'More than 4 years ago',
#        'NA - I am an independent contractor or self employed'],
#       dtype=object)

# %% [markdown]
# ### Assignment:
#
# Q1 - remove rows from 1000 to 1050
#
# Q2- Remove rows where Age is missing
#
# Q3 - Remove features about the personal info of developer
#
# Q4-Remove developers who are  'Neither satisfied nor dissatisfied'
#
# Q5-Filter deveMopers who are looking forward to work with MySQL data base next year
#
# Q6 - filter developers who got hired less than a year ago and let mw know their age and where are they actually from?

# %% [markdown]
# ## Day_000

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4['LanguageWorkedWith']
# Out:
# Respondent
# 1                                     HTML/CSS;Java;JavaScript;Python
# 2                                                 C++;HTML/CSS;Python
# 3                                                            HTML/CSS
# 4                                                 C;C++;C#;Python;SQL
# 5                         C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                      ...
# 88377                                   HTML/CSS;JavaScript;Other(s):
# 88601                                                             NaN
# 88802                                                             NaN
# 88816                                                             NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript;PHP;SQL;Swift
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt3=df4['LanguageWorkedWith'].str.contains("VBA",na=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 filt3=df4['LanguageWorkedWith'].str.contains("VBA",na=False)
# ----> 2 df3.loc[filt3,['LanguageWorkedWith','Country']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df4.loc[filt3,['LanguageWorkedWith','Country']]
# Out:
#                                                                                              LanguageWorkedWith  \
# Respondent
# 5                                                                   C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 16                                                  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 26                    Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScript;PHP;Python;Ruby;SQL;Swift;TypeScript;VBA
# 61                                                                C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 62              Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Ruby;SQL;TypeScript;VBA
# ...                                                                                                         ...
# 75103                                                                                                  Java;VBA
# ...

# %% [markdown]
# ## Perform some updations

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4['ConvertedComp']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
schema2.loc['ConvertedComp']
# Out:
# QuestionText    Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 worki...
# Name: ConvertedComp, dtype: object

# %%
df4.rename(columns={'ConvertedComp':"SalaryUSD"},inplace=True)

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4.rename(columns={"WorkLoc":"WorkingLocation","DevType":"DeveloperType"},inplace=True)

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DeveloperType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkingLocation', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4['CurrencySymbol'].nunique()
# Out:
# 130

# %% [markdown]
# ### changing values

# %%
df4['Hobbyist'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df4['Hobbyist'].map({'Yes':True,"No":False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df4['Hobbyist']=df4['Hobbyist'].map({'Yes':True,"No":False})

# %%
df4['Hobbyist'].unique()
# Out:
# array([ True, False])

# %%
#map will make all other values into Nan

# %%
#replace

# %%
df4['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
df4[(df4['Age1stCode']=='Younger than 5 years') ].shape
# Out:
# (520, 84)

# %%
df4[(df4['Age1stCode']=='Older than 85') ].shape
# Out:
# (26, 84)

# %%
df4['Age1stCode']=df4['Age1stCode'].replace('Younger than 5 years',5)

# %%
df4['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 5, '33', '25', '26', '39', '36', '38', '28', '31',
#        'Older than 85', '32', '37', '50', '65', '42', '34', '40', '67',
#        '43', '44', '60', '46', '45', '49', '51', '41', '55', '83', '48',
#        '53', '54', '47', '56', '79', '61', '68', '77', '66', '52', '80',
#        '62', '84', '57', '58', '63'], dtype=object)

# %%
df4['Age1stCode']=df4['Age1stCode'].replace('Older than 85',85)

# %%
df4['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 5, '33', '25', '26', '39', '36', '38', '28', '31', 85,
#        '32', '37', '50', '65', '42', '34', '40', '67', '43', '44', '60',
#        '46', '45', '49', '51', '41', '55', '83', '48', '53', '54', '47',
#        '56', '79', '61', '68', '77', '66', '52', '80', '62', '84', '57',
#        '58', '63'], dtype=object)

# %%
df4.isnull().sum()
# Out:
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
# Employment       1702
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 84, dtype: int64

# %% [markdown]
# ### Dealing with Nan Values

# %% [markdown]
# > Feature Drops
#
# > Drops Rows
#
# > Imputation(Filling with other values)

# %%
#Feature Drops
df4['SalaryUSD'].isnull().sum()
# Out:
# 33060

# %%
df4['SalaryUSD'].isnull().sum()/df4['SalaryUSD'].shape[0]#if it is more than 90% then you can think about droping features
# Out:
# 0.3719496416637602

# %%
#Drops Rows
df4[df4['SalaryUSD'].isnull()]
# Out:
#                                         MainBranch  Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      True
# 2           I am a student who is learning to code     False
# 5                   I am a developer by profession      True
# 7                   I am a developer by profession     False
# 8                      I code primarily as a hobby      True
# ...                                            ...       ...
# 88377                                          NaN      True
# 88601                                          NaN     False
# 88802                                          NaN     False
# 88816                                          NaN     False
# 88863                                          NaN      True
#
#                                                    OpenSourcer  \
# Respondent
# 1                                                        Never
# 2                                      Less than once per year
# ...

# %%
#Imputation(Filling with other values)

# %%
df4['Age1stCode'].fillna(df4['Age1stCode'].mode()[0],inplace=True)

# %%
df4['Age1stCode'].value_counts()
# Out:
# 15    9930
# 16    8633
# 14    8452
# 18    7945
# 12    7735
#       ...
# 62       1
# 84       1
# 57       1
# 58       1
# 63       1
# Name: Age1stCode, Length: 69, dtype: int64

# %%
df4['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', '27',
#        '24', 5, '33', '25', '26', '39', '36', '38', '28', '31', 85, '32',
#        '37', '50', '65', '42', '34', '40', '67', '43', '44', '60', '46',
#        '45', '49', '51', '41', '55', '83', '48', '53', '54', '47', '56',
#        '79', '61', '68', '77', '66', '52', '80', '62', '84', '57', '58',
#        '63'], dtype=object)

# %%
df4['Age1stCode'].dtype
# Out:
# dtype('O')

# %%
#converting object into integer

# %%
df4['Age1stCode']=df4['Age1stCode'].astype("int64")

# %%
df4['Age1stCode'].dtype
# Out:
# dtype('int64')

# %%
# df4['SalaryUSD'].dtype

# %%
df4['Age1stCode'].unique()
# Out:
# array([10, 17, 22, 16, 14, 15, 11, 20, 13, 18, 12, 19, 21,  8, 35,  6,  9,
#        29,  7,  5, 23, 30, 27, 24, 33, 25, 26, 39, 36, 38, 28, 31, 85, 32,
#        37, 50, 65, 42, 34, 40, 67, 43, 44, 60, 46, 45, 49, 51, 41, 55, 83,
#        48, 53, 54, 47, 56, 79, 61, 68, 77, 66, 52, 80, 62, 84, 57, 58, 63],
#       dtype=int64)

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'DevType',
#        'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat',
#        'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs',
#        'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn',
#        'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
# ...

# %%
df4['EdLevel'].isnull().sum()
# Out:
# 2493

# %%
df4['EdLevel'].dropna(inplace=True)

# %%
df4['EdLevel'].unique()
# Out:
# array(['Primary/elementary school',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Bachelor’s degree (BA, BS, B.Eng., etc.)',
#        'Some college/university study without earning a degree',
#        'Master’s degree (MA, MS, M.Eng., MBA, etc.)',
#        'Other doctoral degree (Ph.D, Ed.D., etc.)', nan,
#        'Associate degree', 'Professional degree (JD, MD, etc.)',
#        'I never completed any formal education'], dtype=object)

# %%
df4['EdLevel'].isnull().sum()
# Out:
# 2493

# %%
df4['EdLevel'].shape[0]
# Out:
# 88883

# %%
df4['SalaryUSD'].isnull().sum()
# Out:
# 33060

# %%
df4['SalaryUSD']=df4['SalaryUSD'].dropna()

# %%
df4['SalaryUSD'].isnull().sum()
# Out:
# 33060

# %%
df5 = df4.copy()

# %%
df5.isnull().sum()
# Out:
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
# Employment       1702
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 84, dtype: int64

# %%
df5.dropna(inplace=True)

# %%
df5.shape
# Out:
# (3476, 84)

# %%
df5.isnull().sum()
# Out:
# MainBranch      0
# Hobbyist        0
# OpenSourcer     0
# OpenSource      0
# Employment      0
#                ..
# Sexuality       0
# Ethnicity       0
# Dependents      0
# SurveyLength    0
# SurveyEase      0
# Length: 84, dtype: int64

# %%
df4['SalaryUSD'].isnull().sum()
# Out:
# 33060

# %%
df4=df4.dropna(subset=['SalaryUSD'])

# %%
df4['SalaryUSD'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Values Sorting

# %%
df4.head()
# Out:
#                                                                                MainBranch  \
# Respondent
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 6           I am not primarily a developer, but I write code sometimes as part of my work
# 9                                                          I am a developer by profession
# 10                                                         I am a developer by profession
#
#             Hobbyist                 OpenSourcer  \
# Respondent
# 3               True                       Never
# 4              False                       Never
# 6               True                       Never
# 9               True  Once a month or more often
# 10              True  Once a month or more often
#
#                                                                                  OpenSource  \
# ...

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DeveloperType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkingLocation', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4.sort_values(by="Country")
# Out:
#                                                                                MainBranch  \
# Respondent
# 48436                                                      I am a developer by profession
# 22450                                                      I am a developer by profession
# 39258                                                      I am a developer by profession
# 8149                                                       I am a developer by profession
# 722                                                        I am a developer by profession
# ...                                                                                   ...
# 84155       I am not primarily a developer, but I write code sometimes as part of my work
# 6492                                                       I am a developer by profession
# 1886                                                       I am a developer by profession
# ...

# %%
df4.sort_values(by="Age")
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 28682       I am a developer by profession      True
# 30774       I am a developer by profession     False
# 84666       I am a developer by profession      True
# 12218       I am a developer by profession      True
# 71939       I am a developer by profession      True
# ...                                    ...       ...
# 88730       I am a developer by profession      True
# 88767       I am a developer by profession      True
# 88826       I am a developer by profession      True
# 88854       I am a developer by profession      True
# 88882       I am a developer by profession      True
#
#                                                    OpenSourcer  \
# Respondent
# 28682                                                    Never
# 30774                                                    Never
# 84666       Less than once a month but more than once per year
# ...

# %%
pd.set_option('display.min_rows',100)

# %%
df4.sort_values(by=['Country','Age'])
# Out:
#                                                                                MainBranch  \
# Respondent
# 722                                                        I am a developer by profession
# 8149                                                       I am a developer by profession
# 10746                                                      I am a developer by profession
# 22450                                                      I am a developer by profession
# 48436                                                      I am a developer by profession
# 7085                                                       I am a developer by profession
# 29736                                                      I am a developer by profession
# 39258                                                      I am a developer by profession
# 58450                                                      I am a developer by profession
# ...

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DeveloperType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkingLocation', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4.sort_values("Country",ascending=False).loc[:50,['YearsCode',"Country"]]
# Out:
#                    YearsCode   Country
# Respondent
# 54422                      3  Zimbabwe
# 76594                     13  Zimbabwe
# 83850                      3  Zimbabwe
# 1886                      11  Zimbabwe
# 30743                      6  Zimbabwe
# 47247                      4  Zimbabwe
# 55405                     10  Zimbabwe
# 35092                      7  Zimbabwe
# 15299                      6  Zimbabwe
# 66459                      9  Zimbabwe
# 15930                     27  Zimbabwe
# 82752                     14  Zimbabwe
# 6492                      16  Zimbabwe
# 2530                       5  Zimbabwe
# 84155                      5  Zimbabwe
# 42413                      4    Zambia
# 29902                      7    Zambia
# 30549                      5    Zambia
# 62116                     15    Zambia
# 65427                      1    Zambia
# 54236                      5    Zambia
# 11557                      7    Zambia
# 65793                      7    Zambia
# ...

# %%
df4.sort_values('Gender').loc[:50,['YearsCode',"Country",'Gender']]
# Out:
#            YearsCode             Country Gender
# Respondent
# 3                  3            Thailand    Man
# 58107              8             Algeria    Man
# 58108             22             Germany    Man
# 58110             25             Germany    Man
# 58111             15             Germany    Man
# 58112             10             Germany    Man
# 58113              4         Philippines    Man
# 58114             30              Norway    Man
# 58115             30       United States    Man
# 58117             12             Denmark    Man
# 58119              3              Brazil    Man
# 58120             18             Germany    Man
# 58122              9             Germany    Man
# 58124             10             Germany    Man
# 58125              9               India    Man
# 58128             11         Netherlands    Man
# 58135              7         Netherlands    Man
# 58136             17             Germany    Man
# ...

# %%
df4['Gender'].unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man'], dtype=object)

# %%
#want to see highest earners from each country

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df4.sort_values(['Country','SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df4[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 722         Afghanistan        0.0
# 28638       Afghanistan        0.0
# 38308           Albania   187668.0
# 3787            Albania   114550.0
# 9270            Albania    74474.0
# 6716            Albania    60000.0
# 10303           Albania    57300.0
# 66280           Albania    41244.0
# 28873           Albania    34368.0
# 64793           Albania    33120.0
# 38928           Albania    24729.0
# 36574           Albania    23952.0
# 80436           Albania    23652.0
# 50326           Albania    23376.0
# 85878           Albania    23376.0
# ...

# %% [markdown]
# ## Assignments
#
# Q1-Change column names of any 5 features
#
# Q2-Change Gender 'man' into Male and 'women' into Female
#
# Q3-Change all CurrencySymbol with CurrencyDesc
#
# Q4-replace developers who earns more than 1900000 into 1900000
#
# Q5-Fill all the nan values of WorkingLocation with appropriate values
#
# Q6-If developer started his coding less than 10 years of age and if they are not getting any combensation give them 1 Lakh
#
# Q7-Fill nan of jos satisfaction with the condition of most developers
#
# Q8-Change data type of YearsCode into float64 (do all the required operations)
#
# Q9-Drop nan values of Ethnicity and Sexuality in a single operation
#
# Q10-Sort values by Employment and Age

# %% [markdown]
# ## Aggregates
